# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/TechLabs/02_Data\ Manipulation/Part\ C\ -\ Pandas

# %% [markdown]
# # Chapter 08 - Grouping and Aggregating - Analyzing and Exploring Your Data
# ### Hey Techie,
# Welcome to the eigth notebook of this Pandas tutorial series. We encourage you to take this notebook as a template to code along the instruction video, which you may find at: https://youtu.be/txMdrV1Ut64. In the instruction video, Corey explains how to group and aggregate data using Pandas to extract meaningful insights. As always, at the end of this notebook are practice tasks to test your skills.
#
# **Here you may find the Pandas documentation:** https://pandas.pydata.org/docs/reference/index.html
#
# #### Have fun! :-)
#
# *Video length*: 50 minutes
# *Self-study time*: 50 minutes
# *Total*: **100 minutes**
# <hr style="border:2px solid gray"> </hr>
#
# ## Real-word Example

# %%
# This is the convention used to import Pandas.
import pandas as pd

# %%
# These options help us to inspect our data more easily.
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
# These commands load the same survey data Corey is using in his video.
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")

# %%
# START YOUR CODE HERE.

df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# /var/folders/wv/4ykr26xn1xz7lvsm_2btgjc00000gn/T/ipykernel_5493/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# DevType                 Which of the following describe you? Please se...
# YearsCode               Including any education, how many years have y...
# Age1stCode              At what age did you write your first line of c...
# YearsCodePro            How many years have you coded professionally (...
# CareerSat               Overall, how satisfied are you with your caree...
# JobSat                  How satisfied are you with your current job? (...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# JobSeek                 Which of the following best describes your cur...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# JobFactors              Imagine that you are deciding between two job ...
# ResumeUpdate            Think back to the last time you updated your r...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CompTotal               What is your current total compensation (salar...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# ConvertedComp           Salary converted to annual USD salaries using ...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkPlan                          How structured or planned is your work?
# WorkChallenge           Of these options, what are your greatest chall...
# WorkRemote                                How often do you work remotely?
# WorkLoc                                   Where would you prefer to work?
# ImpSyn                  For the specific work you do, and the years of...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# UnitTests               Does your company regularly employ unit tests ...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# DatabaseWorkedWith      Which of the following database environments h...
# DatabaseDesireNextYear  Which of the following database environments h...
# PlatformWorkedWith      Which of the following platforms have you done...
# PlatformDesireNextYear  Which of the following platforms have you done...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# DevEnviron              Which development environment(s) do you use re...
# OpSys                   What is the primary operating system in which ...
# Containers              How do you use containers (Docker, Open Contai...
# BlockchainOrg           How is your organization thinking about or imp...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BetterLife              Do you think people born today will have a bet...
# ITperson                 Are you the "IT support person" for your family?
# OffOn                         Have you tried turning it off and on again?
# SocialMedia                   What social media site do you use the most?
# Extraversion              Do you prefer online chat or IRL conversations?
# ScreenName                                           What do you call it?
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# SOFindAnswer            On average, how many times a week do you find ...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOAccount                           Do you have a Stack Overflow account?
# SOPartFreq              How frequently would you say you participate i...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# SOComm                  Do you consider yourself a member of the Stack...
# WelcomeChange           Compared to last year, how welcome do you feel...
# SONewContent            Would you like to see any of the following on ...
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following do you currently identi...
# Trans                                     Do you identify as transgender?
# Sexuality               Which of the following do you currently identi...
# Ethnicity               Which of the following do you identify as? Ple...
# Dependents              Do you have any dependents (e.g., children, el...
# SurveyLength            How do you feel about the length of the survey...
# SurveyEase              How easy or difficult was this survey to compl...

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
# process

# spliting the object
# applying the function
# combining results
# Out:
#   Input In [24]
#     spliting the object
#              ^
# SyntaxError: invalid syntax

# %%
df['Country']
# Out:
# Respondent
# 1                United Kingdom
# 2        Bosnia and Herzegovina
# 3                      Thailand
# 4                 United States
# 5                       Ukraine
#                   ...
# 88377                    Canada
# 88601                       NaN
# 88802                       NaN
# 88816                       NaN
# 88863                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
df.groupby(['Country'])

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# 23                                    Less than once per year
# 26                                    Less than once per year
# ...                                                       ...
# 78292                              Once a month or more often
# 82717                                 Less than once per year
# 83397                                 Less than once per year
# 85642                                 Less than once per year
# 88282                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# 22          OSS is, on average, of HIGHER quality than pro...
# 23          The quality of OSS and closed source software ...
# 26          The quality of OSS and closed source software ...
# ...                                                       ...
# 78292       OSS is, on average, of HIGHER quality than pro...
# 82717       The quality of OSS and closed source software ...
# 83397                                                     NaN
# 85642       OSS is, on average, of LOWER quality than prop...
# 88282       The quality of OSS and closed source software ...
#
#                                                    Employment        Country  \
# Respondent
# 4                                          Employed full-time  United States
# 13                                         Employed full-time  United States
# 22                                         Employed full-time  United States
# 23                                         Employed full-time  United States
# 26                                         Employed full-time  United States
# ...                                                       ...            ...
# 78292       Independent contractor, freelancer, or self-em...  United States
# 82717                      Not employed, but looking for work  United States
# 83397                      Not employed, but looking for work  United States
# 85642       Independent contractor, freelancer, or self-em...  United States
# 88282                      Not employed, but looking for work  United States
#
#            Student                                            EdLevel  \
# Respondent
# 4               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 13              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 22              No  Some college/university study without earning ...
# 23              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 26              No  Some college/university study without earning ...
# ...            ...                                                ...
# 78292           No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 82717           No  Secondary school (e.g. American high school, G...
# 83397           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 85642           No                                   Associate degree
# 88282           No  Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 4           Computer science, computer engineering, or sof...
# 13          Computer science, computer engineering, or sof...
# 22                                                        NaN
# 23          Information systems, information technology, o...
# 26          Computer science, computer engineering, or sof...
# ...                                                       ...
# 78292       A health science (ex. nursing, pharmacy, radio...
# 82717                                                     NaN
# 83397       Computer science, computer engineering, or sof...
# 85642       Information systems, information technology, o...
# 88282       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 4           Taken an online course in programming or softw...
# 13          Taken an online course in programming or softw...
# 22          Taken an online course in programming or softw...
# 23          Taken an online course in programming or softw...
# 26          Taught yourself a new language, framework, or ...
# ...                                                       ...
# 78292       Completed an industry certification program (e...
# 82717                                                     NaN
# 83397       Taken an online course in programming or softw...
# 85642       Taken an online course in programming or softw...
# 88282       Taught yourself a new language, framework, or ...
#
#                                                       OrgSize  \
# Respondent
# 4                                        100 to 499 employees
# 13                                         10 to 19 employees
# 22                                   10,000 or more employees
# 23                                   10,000 or more employees
# 26                                   10,000 or more employees
# ...                                                       ...
# 78292       Just me - I am a freelancer, sole proprietor, ...
# 82717                                                     NaN
# 83397                                                     NaN
# 85642       Just me - I am a freelancer, sole proprietor, ...
# 88282                                                     NaN
#
#                                                       DevType  \
# Respondent
# 4                                       Developer, full-stack
# 13          Data or business analyst;Database administrato...
# 22          Data or business analyst;Designer;Developer, b...
# 23                                      Developer, full-stack
# 26          Designer;Developer, back-end;Developer, deskto...
# ...                                                       ...
# 78292                                     Academic researcher
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                Designer;Marketing or sales professional
# 88282       Developer, back-end;Developer, desktop or ente...
#
#                    YearsCode Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 4                          3         16  Less than 1 year      Very satisfied
# 13                        17         11                 8      Very satisfied
# 22                        35         12                18  Slightly satisfied
# 23                         3         19                 1  Slightly satisfied
# 26                        12          8                 8      Very satisfied
# ...                      ...        ...               ...                 ...
# 78292                     42         14                31                 NaN
# 82717       Less than 1 year        NaN  Less than 1 year                 NaN
# 83397                     12          9  Less than 1 year                 NaN
# 85642                     20          7  Less than 1 year                 NaN
# 88282                     38         10                38                 NaN
#
#                         JobSat            MgrIdiot MgrMoney   MgrWant  \
# Respondent
# 4           Slightly satisfied      Very confident       No  Not sure
# 13              Very satisfied                 NaN      NaN       NaN
# 22           Very dissatisfied  Somewhat confident       No        No
# 23          Slightly satisfied      Very confident       No  Not sure
# 26              Very satisfied                 NaN      NaN       NaN
# ...                        ...                 ...      ...       ...
# 78292                      NaN                 NaN      NaN       NaN
# 82717                      NaN                 NaN      NaN       NaN
# 83397                      NaN                 NaN      NaN       NaN
# 85642                      NaN                 NaN      NaN       NaN
# 88282                      NaN                 NaN      NaN       NaN
#
#                                                       JobSeek  \
# Respondent
# 4                I am not interested in new job opportunities
# 13               I am not interested in new job opportunities
# 22          I’m not actively looking, but I am open to new...
# 23          I’m not actively looking, but I am open to new...
# 26          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                      LastHireDate  \
# Respondent
# 4            Less than a year ago
# 13                  3-4 years ago
# 22          More than 4 years ago
# 23           Less than a year ago
# 26           Less than a year ago
# ...                           ...
# 78292                         NaN
# 82717                         NaN
# 83397                         NaN
# 85642                         NaN
# 88282                         NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 13          Complete a take-home project;Interview with pe...      Yes
# 22          Interview with people in senior / management r...       No
# 23          Write any code;Write code by hand (e.g., on a ...       No
# 26          Interview with people in peer roles;Interview ...       No
# ...                                                       ...      ...
# 78292                                                     NaN      NaN
# 82717                                                     NaN      NaN
# 83397                                                     NaN      NaN
# 85642                                                     NaN      NaN
# 88282                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 4           Languages, frameworks, and other technologies ...
# 13          Languages, frameworks, and other technologies ...
# 22          Industry that I'd be working in;Financial perf...
# 23          Opportunities for professional development;How...
# 26          Remote work options;Diversity of the company o...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 4                            I was preparing for a job search            USD
# 13                           I was preparing for a job search            USD
# 22          I had a negative experience or interaction at ...            USD
# 23                           I was preparing for a job search            USD
# 26                           I was preparing for a job search            USD
# ...                                                       ...            ...
# 78292                                                     NaN            NaN
# 82717                                                     NaN            NaN
# 83397                                                     NaN            NaN
# 85642                                                     NaN            NaN
# 88282                                                     NaN            NaN
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 4           United States dollar    61000.0   Yearly        61000.0
# 13          United States dollar    90000.0   Yearly        90000.0
# 22          United States dollar   103000.0   Yearly       103000.0
# 23          United States dollar    69000.0   Yearly        69000.0
# 26          United States dollar   114000.0   Yearly       114000.0
# ...                          ...        ...      ...            ...
# 78292                        NaN        NaN      NaN            NaN
# 82717                        NaN        NaN      NaN            NaN
# 83397                        NaN        NaN      NaN            NaN
# 85642                        NaN        NaN      NaN            NaN
# 88282                        NaN        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 4                  80.0  There's no schedule or spec; I work on what se...
# 13                 40.0  There is a schedule and/or spec (made by me or...
# 22                 40.0  There is a schedule and/or spec (made by me or...
# 23                 40.0  There is a schedule and/or spec (made by me or...
# 26                 40.0  There is a schedule and/or spec (made by me or...
# ...                 ...                                                ...
# 78292               NaN                                                NaN
# 82717               NaN                                                NaN
# 83397               NaN                                                NaN
# 85642               NaN                                                NaN
# 88282               NaN                                                NaN
#
#                                                 WorkChallenge  \
# Respondent
# 4                                                         NaN
# 13          Meetings;Non-work commitments (parenting, scho...
# 22          Being tasked with non-development work;Meeting...
# 23          Distracting work environment;Meetings;Non-work...
# 26          Being tasked with non-development work;Meeting...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 4                            Less than once per month / Never    Home
# 13          All or almost all the time (I'm full-time remote)    Home
# 22          Less than half the time, but at least one day ...    Home
# 23                                      A few days each month  Office
# 26          Less than half the time, but at least one day ...    Home
# ...                                                       ...     ...
# 78292                                                     NaN     NaN
# 82717                                                     NaN     NaN
# 83397                                                     NaN     NaN
# 85642                                                     NaN     NaN
# 88282                                                     NaN     NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 4           A little below average                                       No
# 13          A little above average  Yes, because I see value in code review
# 22                         Average                                       No
# 23                         Average  Yes, because I see value in code review
# 26               Far above average  Yes, because I see value in code review
# ...                            ...                                      ...
# 78292                          NaN                                      NaN
# 82717                          NaN                                      NaN
# 83397                          NaN                                      NaN
# 85642                          NaN                                      NaN
# 88282                          NaN                                      NaN
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 4                  NaN                          No, but I think we should
# 13                 5.0                          No, but I think we should
# 22                 NaN                          No, but I think we should
# 23                 8.0                      Yes, it's part of our process
# 26                 2.0  Yes, it's not part of our process but the deve...
# ...                ...                                                ...
# 78292              NaN                                                NaN
# 82717              NaN                                                NaN
# 83397              NaN                                                NaN
# 85642              NaN                                                NaN
# 88282              NaN                                                NaN
#
#                                                   PurchaseHow  \
# Respondent
# 4           Developers typically have the most influence o...
# 13          Developers and management have nearly equal in...
# 22          The CTO, CIO, or other management purchase new...
# 23          Developers and management have nearly equal in...
# 26          Developers typically have the most influence o...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 4              I have little or no influence
# 13          I have a great deal of influence
# 22             I have little or no influence
# 23             I have little or no influence
# 26          I have a great deal of influence
# ...                                      ...
# 78292                                    NaN
# 82717                                    NaN
# 83397                                    NaN
# 85642                                    NaN
# 88282                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 4                                         C;C++;C#;Python;SQL
# 13          Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 23          Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 26          Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# ...                                                       ...
# 78292                          Bash/Shell/PowerShell;C;Python
# 82717                                                     NaN
# 83397                          HTML/CSS;JavaScript;Python;SQL
# 85642                                             Go;HTML/CSS
# 88282       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 4                                         C;C#;JavaScript;SQL
# 13          Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 23          Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 26          C#;HTML/CSS;JavaScript;Objective-C;Ruby;SQL;Sw...
# ...                                                       ...
# 78292                          Bash/Shell/PowerShell;C;Python
# 82717                                                     NaN
# 83397       C;C++;C#;Go;Java;JavaScript;Python;R;Ruby;SQL;...
# 85642                                                     NaN
# 88282       Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
#
#                                  DatabaseWorkedWith  \
# Respondent
# 4                                      MySQL;SQLite
# 13                Couchbase;DynamoDB;Firebase;MySQL
# 22                 Elasticsearch;MySQL;Oracle;Redis
# 23                                    Oracle;SQLite
# 26          Microsoft SQL Server;MySQL;Redis;SQLite
# ...                                             ...
# 78292                                        SQLite
# 82717                                           NaN
# 83397                                           NaN
# 85642                                           NaN
# 88282                                           NaN
#
#                                       DatabaseDesireNextYear  \
# Respondent
# 4                                               MySQL;SQLite
# 13                                      Firebase;MySQL;Redis
# 22                          Elasticsearch;MySQL;Oracle;Redis
# 23          Couchbase;DynamoDB;Elasticsearch;Firebase;Oracle
# 26                   Microsoft SQL Server;MySQL;Redis;SQLite
# ...                                                      ...
# 78292                                                 SQLite
# 82717                                                    NaN
# 83397                                                    NaN
# 85642                                                    NaN
# 88282                                                    NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 4                                               Linux;Windows
# 13          Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 22                          Docker;Linux;Raspberry Pi;Windows
# 23                               Docker;Google Cloud Platform
# 26          AWS;Docker;Linux;MacOS;Microsoft Azure;Windows...
# ...                                                       ...
# 78292                            Linux;Raspberry Pi;Other(s):
# 82717                                         Android;Windows
# 83397                                   Android;Arduino;Slack
# 85642                                                     NaN
# 88282                                                   Linux
#
#                                        PlatformDesireNextYear  \
# Respondent
# 4                                               Linux;Windows
# 13          Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# 22                          Docker;Linux;Raspberry Pi;Windows
# 23                                           Docker;iOS;Slack
# 26          Android;Docker;iOS;Linux;MacOS;Microsoft Azure...
# ...                                                       ...
# 78292                            Linux;Raspberry Pi;Other(s):
# 82717                         Android;Microsoft Azure;Windows
# 83397           Android;Arduino;Docker;iOS;Raspberry Pi;Slack
# 85642                                                     NaN
# 88282                                      Linux;Raspberry Pi
#
#                                            WebFrameWorkedWith  \
# Respondent
# 4                                                         NaN
# 13           Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# 22                           Angular/Angular.js;Ruby on Rails
# 23                                     React.js;Ruby on Rails
# 26          Angular/Angular.js;ASP.NET;Drupal;Express;jQue...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                   Flask
# 85642                                                     NaN
# 88282                                                React.js
#
#                            WebFrameDesireNextYear  \
# Respondent
# 4                                             NaN
# 13                                 Express;Vue.js
# 22               Angular/Angular.js;Ruby on Rails
# 23          Express;React.js;Ruby on Rails;Vue.js
# 26                     Angular/Angular.js;ASP.NET
# ...                                           ...
# 78292                                         NaN
# 82717                                         NaN
# 83397         Django;Drupal;Flask;jQuery;React.js
# 85642                                         NaN
# 88282                                      Vue.js
#
#                         MiscTechWorkedWith   MiscTechDesireNextYear  \
# Respondent
# 4                                     .NET                     .NET
# 13                         Node.js;Xamarin       Node.js;TensorFlow
# 22                                 Node.js                  Node.js
# 23                                     NaN  React Native;TensorFlow
# 26          .NET;.NET Core;Node.js;Xamarin   .NET;.NET Core;Node.js
# ...                                    ...                      ...
# 78292                                 Chef                      NaN
# 82717                                  NaN                      NaN
# 83397                                  NaN       Chef;Torch/PyTorch
# 85642                                  NaN                      NaN
# 88282                              Node.js                  Ansible
#
#                                                 DevEnviron        OpSys  \
# Respondent
# 4             Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 13              Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# 22           Sublime Text;Visual Studio;Visual Studio Code      Windows
# 23                                      Visual Studio Code        MacOS
# 26          Notepad++;Sublime Text;Vim;Visual Studio;Xcode        MacOS
# ...                                                    ...          ...
# 78292                              Emacs;IPython / Jupyter  Linux-based
# 82717                                                  NaN        MacOS
# 83397               Eclipse;IPython / Jupyter;Sublime Text        MacOS
# 85642                                   Visual Studio Code      Windows
# 88282                                                  Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 4                          I do not use containers    Not at all
# 13                  Development;Testing;Production    Not at all
# 22          Outside of work, for personal projects    Not at all
# 23                  Development;Testing;Production           NaN
# 26                             Development;Testing    Not at all
# ...                                            ...           ...
# 78292                      I do not use containers           NaN
# 82717                                      Testing           NaN
# 83397                      I do not use containers           NaN
# 85642                      I do not use containers           NaN
# 88282                      I do not use containers           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 13          Useful for decentralized currency (i.e., Bitcoin)        Yes
# 22                                                        NaN        Yes
# 23          Useful for immutable record keeping outside of...        Yes
# 26                                              A passing fad        Yes
# ...                                                       ...        ...
# 78292       Useful for immutable record keeping outside of...         No
# 82717                                                     NaN         No
# 83397                                                     NaN        NaN
# 85642       Useful for immutable record keeping outside of...         No
# 88282                       An irresponsible use of resources         No
#
#            ITperson OffOn               SocialMedia              Extraversion  \
# Respondent
# 4              SIGH   Yes                    Reddit  In real life (in person)
# 13              Yes   Yes                   Twitter  In real life (in person)
# 22              Yes   Yes                 Instagram                    Online
# 23             SIGH   Yes                    Reddit  In real life (in person)
# 26             SIGH   Yes  I don't use social media  In real life (in person)
# ...             ...   ...                       ...                       ...
# 78292           Yes   Yes  I don't use social media  In real life (in person)
# 82717          SIGH   Yes                  Facebook  In real life (in person)
# 83397          SIGH   Yes                       NaN                       NaN
# 85642          SIGH   Yes                       NaN  In real life (in person)
# 88282           NaN   Yes  I don't use social media  In real life (in person)
#
#            ScreenName        SOVisit1st                          SOVisitFreq  \
# Respondent
# 4            Username              2014                Daily or almost daily
# 13           Username              2011               Multiple times per day
# 22           Username  I don't remember                Daily or almost daily
# 23           Username              2014               Multiple times per day
# 26           Username              2008                Daily or almost daily
# ...               ...               ...                                  ...
# 78292             NaN              2013                 A few times per week
# 82717        Username              2018  Less than once per month or monthly
# 83397          Handle  I don't remember                 A few times per week
# 85642          Handle              2008  Less than once per month or monthly
# 88282        Username  I don't remember      A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 4           Find answers to specific questions;Pass the ti...
# 13                         Find answers to specific questions
# 22                         Find answers to specific questions
# 23          Find answers to specific questions;Learn how t...
# 26          Find answers to specific questions;Learn how t...
# ...                                                       ...
# 78292                      Find answers to specific questions
# 82717                      Find answers to specific questions
# 83397       Find answers to specific questions;Learn how t...
# 85642                      Find answers to specific questions
# 88282                      Find answers to specific questions
#
#                            SOFindAnswer  \
# Respondent
# 4                    1-2 times per week
# 13          More than 10 times per week
# 22                   3-5 times per week
# 23                  6-10 times per week
# 26                   3-5 times per week
# ...                                 ...
# 78292           Less than once per week
# 82717           Less than once per week
# 83397                3-5 times per week
# 85642           Less than once per week
# 88282                1-2 times per week
#
#                                        SOTimeSaved  SOHowMuchTime  \
# Respondent
# 4                   Stack Overflow was much faster  31-60 minutes
# 13                  Stack Overflow was much faster  11-30 minutes
# 22                  Stack Overflow was much faster   0-10 minutes
# 23                        They were about the same            NaN
# 26                  Stack Overflow was much faster  11-30 minutes
# ...                                            ...            ...
# 78292       The other resource was slightly faster  11-30 minutes
# 82717                                          NaN    60+ minutes
# 83397                     They were about the same            NaN
# 85642           Stack Overflow was slightly faster    60+ minutes
# 88282                     They were about the same            NaN
#
#                             SOAccount  \
# Respondent
# 4                                 Yes
# 13                                Yes
# 22                                Yes
# 23                                Yes
# 26                                Yes
# ...                               ...
# 78292       Not sure / can't remember
# 82717                              No
# 83397       Not sure / can't remember
# 85642                             Yes
# 88282                             Yes
#
#                                                    SOPartFreq  \
# Respondent
# 4                         Less than once per month or monthly
# 13                        Less than once per month or monthly
# 22                                       A few times per week
# 23          I have never participated in Q&A on Stack Over...
# 26                        Less than once per month or monthly
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642       I have never participated in Q&A on Stack Over...
# 88282       I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 4                                                         Yes
# 13                                                        Yes
# 22                                                        Yes
# 23                                                        Yes
# 26                                                        Yes
# ...                                                       ...
# 78292       No, I didn't know that Stack Overflow had a jo...
# 82717       No, I knew that Stack Overflow had a job board...
# 83397                                                     Yes
# 85642       No, I knew that Stack Overflow had a job board...
# 88282                                                     Yes
#
#                                                      EntTeams          SOComm  \
# Respondent
# 4                         No, and I don't know what those are  No, not really
# 13          No, I've heard of them, but I am not part of a...         Neutral
# 22                        No, and I don't know what those are   Yes, somewhat
# 23          No, I've heard of them, but I am not part of a...  No, not really
# 26          No, I've heard of them, but I am not part of a...         Neutral
# ...                                                       ...             ...
# 78292                     No, and I don't know what those are  No, not really
# 82717       No, I've heard of them, but I am not part of a...        Not sure
# 83397                     No, and I don't know what those are  No, not at all
# 85642                     No, and I don't know what those are  No, not at all
# 88282                     No, and I don't know what those are  No, not really
#
#                                        WelcomeChange  \
# Respondent
# 4            Just as welcome now as I felt last year
# 13          Somewhat more welcome now than last year
# 22           Just as welcome now as I felt last year
# 23           Just as welcome now as I felt last year
# 26           Just as welcome now as I felt last year
# ...                                              ...
# 78292       Somewhat less welcome now than last year
# 82717                                            NaN
# 83397        Just as welcome now as I felt last year
# 85642        Just as welcome now as I felt last year
# 88282        Just as welcome now as I felt last year
#
#                                                  SONewContent   Age  \
# Respondent
# 4           Tech articles written by other developers;Indu...  22.0
# 13          Tech articles written by other developers;Cour...  28.0
# 22          Tech articles written by other developers;Indu...  47.0
# 23          Tech articles written by other developers;Tech...  22.0
# 26                                                        NaN  34.0
# ...                                                       ...   ...
# 78292                                                     NaN  60.0
# 82717       Industry news about technologies you're intere...  44.0
# 83397                                                     NaN  27.0
# 85642       Tech articles written by other developers;Indu...  34.0
# 88282                                                     NaN   NaN
#
#                                                        Gender Trans  \
# Respondent
# 4                                                         Man    No
# 13                                                        Man    No
# 22                                                        Man    No
# 23                                                        Man    No
# 26                                                        Man    No
# ...                                                       ...   ...
# 78292                                                     Man    No
# 82717                                                     Man    No
# 83397                                                   Woman    No
# 85642       Non-binary, genderqueer, or gender non-conforming   NaN
# 88282                                                     Man    No
#
#                           Sexuality                     Ethnicity Dependents  \
# Respondent
# 4           Straight / Heterosexual  White or of European descent         No
# 13          Straight / Heterosexual  White or of European descent        Yes
# 22          Straight / Heterosexual  White or of European descent        Yes
# 23          Straight / Heterosexual   Black or of African descent         No
# 26                   Gay or Lesbian                           NaN         No
# ...                             ...                           ...        ...
# 78292       Straight / Heterosexual  White or of European descent        Yes
# 82717       Straight / Heterosexual  White or of European descent        Yes
# 83397                      Bisexual  White or of European descent         No
# 85642       Bisexual;Gay or Lesbian  White or of European descent         No
# 88282       Straight / Heterosexual                           NaN         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 4           Appropriate in length                        Easy
# 13          Appropriate in length                        Easy
# 22          Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 26          Appropriate in length                        Easy
# ...                           ...                         ...
# 78292                    Too long  Neither easy nor difficult
# 82717       Appropriate in length  Neither easy nor difficult
# 83397       Appropriate in length                        Easy
# 85642       Appropriate in length                        Easy
# 88282                   Too short  Neither easy nor difficult
#
# [20949 rows x 84 columns]

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# ...                                                       ...
# 77339                                 Less than once per year
# 79795       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                        NaN
# ...                                                       ...
# 77339       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India             NaN
# 10                          Employed full-time   India              No
# 15          Not employed, but looking for work   India  Yes, full-time
# 50                          Employed full-time   India              No
# 65                          Employed full-time   India              No
# ...                                        ...     ...             ...
# 77339                       Employed full-time   India  Yes, full-time
# 79795                       Employed full-time   India              No
# 83862                       Employed full-time   India  Yes, full-time
# 84299                       Employed full-time   India  Yes, full-time
# 86012                       Employed full-time   India              No
#
#                                                       EdLevel  \
# Respondent
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Secondary school (e.g. American high school, G...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 77339                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 15                                                        NaN
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# ...                                                       ...
# 77339       Another engineering discipline (ex. civil, ele...
# 79795       Computer science, computer engineering, or sof...
# 83862                                                     NaN
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 8           Taught yourself a new language, framework, or ...
# 10                                                        NaN
# 15          Taken an online course in programming or softw...
# 50          Received on-the-job training in software devel...
# 65                                                        NaN
# ...                                                       ...
# 77339       Taken an online course in programming or softw...
# 79795       Taken an online course in programming or softw...
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 86012       Taught yourself a new language, framework, or ...
#
#                              OrgSize  \
# Respondent
# 8                                NaN
# 10          10,000 or more employees
# 15                               NaN
# 50          10,000 or more employees
# 65                20 to 99 employees
# ...                              ...
# 77339       1,000 to 4,999 employees
# 79795           500 to 999 employees
# 83862                            NaN
# 84299           100 to 499 employees
# 86012           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 8              Developer, back-end;Engineer, site reliability         8
# 10          Data or business analyst;Data scientist or mac...        12
# 15                                                    Student         3
# 50                      Developer, back-end;DevOps specialist         7
# 65                     Developer, front-end;Developer, mobile         2
# ...                                                       ...       ...
# 77339                                                     NaN         1
# 79795                                   Developer, QA or test         6
# 83862                        Data or business analyst;Student         1
# 84299       Developer, back-end;Developer, front-end;Devel...        12
# 86012                            Academic researcher;Educator         5
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 8                  16               NaN                    NaN
# 10                 20                10  Slightly dissatisfied
# 15                 13               NaN                    NaN
# 50                 15                 2     Slightly satisfied
# 65                 17                 2         Very satisfied
# ...               ...               ...                    ...
# 77339              27                 1                    NaN
# 79795              17                 5                    NaN
# 83862              18  Less than 1 year                    NaN
# 84299              25                12                    NaN
# 86012              15               NaN                    NaN
#
#                            JobSat            MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 8                             NaN                 NaN       NaN       NaN
# 10          Slightly dissatisfied  Somewhat confident       Yes       Yes
# 15                            NaN                 NaN       NaN       NaN
# 50                 Very satisfied      Very confident  Not sure       Yes
# 65                 Very satisfied      Very confident        No  Not sure
# ...                           ...                 ...       ...       ...
# 77339                         NaN  Somewhat confident       Yes       Yes
# 79795                         NaN  Somewhat confident        No  Not sure
# 83862                         NaN      Very confident  Not sure       Yes
# 84299                         NaN                 NaN       NaN       NaN
# 86012                         NaN  Somewhat confident        No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 8                                                         NaN
# 10          I’m not actively looking, but I am open to new...
# 15          I’m not actively looking, but I am open to new...
# 50          I’m not actively looking, but I am open to new...
# 65          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 8                            NaN
# 10                 3-4 years ago
# 15          I've never had a job
# 50                 1-2 years ago
# 65          Less than a year ago
# ...                          ...
# 77339                        NaN
# 79795                        NaN
# 83862                        NaN
# 84299                        NaN
# 86012                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 8                                                         NaN      NaN
# 10                                                        NaN       No
# 15                                                        NaN      NaN
# 50          Write code by hand (e.g., on a whiteboard);Int...       No
# 65          Write any code;Solve a brain-teaser style puzz...       No
# ...                                                       ...      ...
# 77339                                                     NaN      NaN
# 79795                                                     NaN      NaN
# 83862                                                     NaN      NaN
# 84299                                                     NaN      NaN
# 86012                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 8                                                         NaN
# 10          Languages, frameworks, and other technologies ...
# 15          Industry that I'd be working in;Languages, fra...
# 50          Specific department or team I'd be working on;...
# 65          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 8                                                         NaN            NaN
# 10                                                        NaN            INR
# 15          Something else changed (education, award, medi...            NaN
# 50                           I was preparing for a job search            INR
# 65           My job status changed (promotion, new job, etc.)            INR
# ...                                                       ...            ...
# 77339                                                     NaN            NaN
# 79795                                                     NaN            NaN
# 83862                                                     NaN            NaN
# 84299                                                     NaN            NaN
# 86012                                                     NaN            NaN
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 8                    NaN        NaN      NaN            NaN          NaN
# 10          Indian rupee   950000.0   Yearly        13293.0         70.0
# 15                   NaN        NaN      NaN            NaN          NaN
# 50          Indian rupee   400000.0   Yearly         5597.0          7.0
# 65          Indian rupee        NaN  Monthly            NaN         48.0
# ...                  ...        ...      ...            ...          ...
# 77339                NaN        NaN      NaN            NaN          NaN
# 79795                NaN        NaN      NaN            NaN          NaN
# 83862                NaN        NaN      NaN            NaN          NaN
# 84299                NaN        NaN      NaN            NaN          NaN
# 86012                NaN        NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 8                                                         NaN
# 10          There's no schedule or spec; I work on what se...
# 15                                                        NaN
# 50          There is a schedule and/or spec (made by me or...
# 65          There's no schedule or spec; I work on what se...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                             WorkChallenge                        WorkRemote  \
# Respondent
# 8                                     NaN                               NaN
# 10                                    NaN             A few days each month
# 15                                    NaN                               NaN
# 50          Meetings;Time spent commuting  Less than once per month / Never
# 65                                    NaN               About half the time
# ...                                   ...                               ...
# 77339                                 NaN                               NaN
# 79795                                 NaN                               NaN
# 83862                                 NaN                               NaN
# 84299                                 NaN                               NaN
# 86012                                 NaN                               NaN
#
#                                                    WorkLoc             ImpSyn  \
# Respondent
# 8                                                      NaN                NaN
# 10                                                    Home  Far above average
# 15                                                     NaN                NaN
# 50          Other place, such as a coworking space or cafe            Average
# 65                                                  Office            Average
# ...                                                    ...                ...
# 77339                                                  NaN                NaN
# 79795                                                  NaN                NaN
# 83862                                                  NaN                NaN
# 84299                                                  NaN                NaN
# 86012                                                  NaN                NaN
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 8                                               NaN         NaN
# 10          Yes, because I see value in code review         4.0
# 15                                              NaN         NaN
# 50                                               No         NaN
# 65          Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 77339                                           NaN         NaN
# 79795                                           NaN         NaN
# 83862                                           NaN         NaN
# 84299                                           NaN         NaN
# 86012                                           NaN         NaN
#
#                                                     UnitTests  \
# Respondent
# 8                                                         NaN
# 10                              Yes, it's part of our process
# 15                                                        NaN
# 50          Yes, it's not part of our process but the deve...
# 65          Yes, it's not part of our process but the deve...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                   PurchaseHow  \
# Respondent
# 8                                                         NaN
# 10                                                        NaN
# 15                                                        NaN
# 50          The CTO, CIO, or other management purchase new...
# 65                                                   Not sure
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                              PurchaseWhat  \
# Respondent
# 8                                     NaN
# 10                                    NaN
# 15                                    NaN
# 50          I have little or no influence
# 65                                    NaN
# ...                                   ...
# 77339                                 NaN
# 79795                                 NaN
# 83862                                 NaN
# 84299                                 NaN
# 86012                                 NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# 77339                                               Other(s):
# 79795                    Bash/Shell/PowerShell;Python;SQL;VBA
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                                 HTML/CSS;JavaScript;Python
# 65                                                     Kotlin
# ...                                                       ...
# 77339                                              Python;SQL
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                HTML/CSS;Java;JavaScript
# 86012                                              C++;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                                MariaDB;MySQL;Oracle;SQLite
# 50          Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                               Firebase;MySQL;Oracle;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                   MySQL
# 84299                                    MongoDB;Redis;SQLite
# 86012                                                   MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
# 15          MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                        Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862             Android;AWS;Google Cloud Platform;WordPress
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                        PlatformDesireNextYear  \
# Respondent
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                         Android;Linux;Raspberry Pi;Windows
# 15          Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50          AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                     IBM Cloud or Watson
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                            WebFrameWorkedWith  \
# Respondent
# 8                               Express;Flask;React.js;Spring
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                        NaN
# 50                                Django;Express;Flask;jQuery
# 65                                                    ASP.NET
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Laravel
# 84299       Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                                     NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 8                        Django;Express;Flask;React.js;Vue.js
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15          Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                       Express;Flask;jQuery;React.js;Vue.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                       Angular/Angular.js;Laravel;Vue.js
# 84299                              Express;React.js;Other(s):
# 86012                                                     NaN
#
#                            MiscTechWorkedWith  \
# Respondent
# 8                       Hadoop;Node.js;Pandas
# 10          .NET;Node.js;Pandas;Torch/PyTorch
# 15                                        NaN
# 50                                    Node.js
# 65                                        NaN
# ...                                       ...
# 77339                                     NaN
# 79795                Apache Spark;Chef;Puppet
# 83862                                     NaN
# 84299                                 Node.js
# 86012                                     NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
# 15          .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                                    Node.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Node.js
# 84299                                                 Node.js
# 86012                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15                   Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                               Notepad++;Visual Studio Code        MacOS
# 65                                    Android Studio;IntelliJ  Linux-based
# ...                                                       ...          ...
# 77339                                                     NaN  Linux-based
# 79795                                             PyCharm;Vim  Linux-based
# 83862       Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299             IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                               Notepad++  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 8           Development;Testing;Production;Outside of work...           NaN
# 10                                                        NaN    Not at all
# 15                                                Development           NaN
# 50                                                    Testing    Not at all
# 65                                                        NaN           NaN
# ...                                                       ...           ...
# 77339                                 I do not use containers           NaN
# 79795       Development;Testing;Production;Outside of work...    Not at all
# 83862                                 I do not use containers           NaN
# 84299                                                     NaN           NaN
# 86012                                 I do not use containers           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 8           Useful across many domains and could change ma...        Yes
# 10          Useful for immutable record keeping outside of...         No
# 15                                                        NaN        Yes
# 50          Useful for immutable record keeping outside of...        Yes
# 65                                                        NaN        Yes
# ...                                                       ...        ...
# 77339                                                     NaN        Yes
# 79795                                                     NaN         No
# 83862       Useful across many domains and could change ma...         No
# 84299                                                     NaN        Yes
# 86012                                                     NaN         No
#
#                                             ITperson  OffOn  \
# Respondent
# 8                                               SIGH    Yes
# 10                                               Yes    Yes
# 15                                               Yes  What?
# 50                                          Also Yes  What?
# 65                                               Yes  What?
# ...                                              ...    ...
# 77339                                            Yes     No
# 79795                                            Yes  What?
# 83862                                            Yes  What?
# 84299       Fortunately, someone else has that title  What?
# 86012                                       Also Yes  What?
#
#                          SocialMedia              Extraversion   ScreenName  \
# Respondent
# 8                            YouTube  In real life (in person)       Handle
# 10                           YouTube                   Neither  Screen Name
# 15                           YouTube  In real life (in person)          NaN
# 50                           YouTube  In real life (in person)     Username
# 65                          WhatsApp  In real life (in person)          NaN
# ...                              ...                       ...          ...
# 77339                        YouTube                    Online       UserID
# 79795                      Instagram  In real life (in person)     Username
# 83862                        Twitter                    Online       UserID
# 84299                       LinkedIn                       NaN          NaN
# 86012       I don't use social media                    Online     Username
#
#            SOVisit1st                          SOVisitFreq  \
# Respondent
# 8                2012                 A few times per week
# 10                NaN               Multiple times per day
# 15               2018                Daily or almost daily
# 50               2012                Daily or almost daily
# 65               2017               Multiple times per day
# ...               ...                                  ...
# 77339            2019  Less than once per month or monthly
# 79795            2018      A few times per month or weekly
# 83862            2012      A few times per month or weekly
# 84299            2011      A few times per month or weekly
# 86012            2014      A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 8           Find answers to specific questions;Learn how t...
# 10          Find answers to specific questions;Get a sense...
# 15          Find answers to specific questions;Learn how t...
# 50          Find answers to specific questions;Learn how t...
# 65                         Find answers to specific questions
# ...                                                       ...
# 77339       Find answers to specific questions;Learn how t...
# 79795                      Find answers to specific questions
# 83862       Find answers to specific questions;Learn how t...
# 84299       Find answers to specific questions;Contribute ...
# 86012                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 8               Less than once per week  Stack Overflow was slightly faster
# 10                   3-5 times per week            They were about the same
# 15          More than 10 times per week            They were about the same
# 50                   3-5 times per week  Stack Overflow was slightly faster
# 65          More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 77339                1-2 times per week      Stack Overflow was much faster
# 79795           Less than once per week            They were about the same
# 83862           Less than once per week      Stack Overflow was much faster
# 84299           Less than once per week      Stack Overflow was much faster
# 86012           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 8           11-30 minutes       Yes
# 10                    NaN       Yes
# 15                    NaN       Yes
# 50          11-30 minutes       Yes
# 65          11-30 minutes       Yes
# ...                   ...       ...
# 77339       31-60 minutes       Yes
# 79795                 NaN       Yes
# 83862        0-10 minutes       Yes
# 84299         60+ minutes       Yes
# 86012       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 8                         Less than once per month or monthly
# 10                            A few times per month or weekly
# 15                        Less than once per month or monthly
# 50                        Less than once per month or monthly
# 65                                       A few times per week
# ...                                                       ...
# 77339       I have never participated in Q&A on Stack Over...
# 79795       I have never participated in Q&A on Stack Over...
# 83862       I have never participated in Q&A on Stack Over...
# 84299                     Less than once per month or monthly
# 86012                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 8                                                         Yes
# 10                                                        Yes
# 15                                                        Yes
# 50          No, I knew that Stack Overflow had a job board...
# 65          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 77339       No, I didn't know that Stack Overflow had a jo...
# 79795       No, I didn't know that Stack Overflow had a jo...
# 83862                                                     Yes
# 84299                                                     Yes
# 86012       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 8                         No, and I don't know what those are
# 10                        No, and I don't know what those are
# 15          No, I've heard of them, but I am not part of a...
# 50                        No, and I don't know what those are
# 65                        No, and I don't know what those are
# ...                                                       ...
# 77339       No, I've heard of them, but I am not part of a...
# 79795                     No, and I don't know what those are
# 83862                     No, and I don't know what those are
# 84299                     No, and I don't know what those are
# 86012                                                     Yes
#
#                      SOComm  \
# Respondent
# 8           Yes, definitely
# 10            Yes, somewhat
# 15            Yes, somewhat
# 50          Yes, definitely
# 65                 Not sure
# ...                     ...
# 77339         Yes, somewhat
# 79795               Neutral
# 83862       Yes, definitely
# 84299         Yes, somewhat
# 86012         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# ...                                                       ...
# 77339       Not applicable - I did not use Stack Overflow ...
# 79795                Somewhat more welcome now than last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN    NaN
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                        NaN  21.0    Man
# ...                                                       ...   ...    ...
# 77339       Tech articles written by other developers;Indu...   NaN    NaN
# 79795       Tech meetups or events in your area;Courses on...   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                     NaN   NaN    NaN
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual          NaN        NaN
# 10           NaN                      NaN          NaN        Yes
# 15            No                      NaN          NaN        Yes
# 50            No                      NaN  South Asian         No
# 65            No                      NaN          NaN        Yes
# ...          ...                      ...          ...        ...
# 77339        NaN                      NaN          NaN        NaN
# 79795         No  Straight / Heterosexual          NaN         No
# 83862         No  Straight / Heterosexual          NaN        Yes
# 84299        NaN                      NaN          NaN        NaN
# 86012         No                      NaN  South Asian        NaN
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 77339                         NaN                         NaN
# 79795                    Too long                   Difficult
# 83862                    Too long  Neither easy nor difficult
# 84299                         NaN                         NaN
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# 23                                    Less than once per year
# 26                                    Less than once per year
# ...                                                       ...
# 78292                              Once a month or more often
# 82717                                 Less than once per year
# 83397                                 Less than once per year
# 85642                                 Less than once per year
# 88282                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# 22          OSS is, on average, of HIGHER quality than pro...
# 23          The quality of OSS and closed source software ...
# 26          The quality of OSS and closed source software ...
# ...                                                       ...
# 78292       OSS is, on average, of HIGHER quality than pro...
# 82717       The quality of OSS and closed source software ...
# 83397                                                     NaN
# 85642       OSS is, on average, of LOWER quality than prop...
# 88282       The quality of OSS and closed source software ...
#
#                                                    Employment        Country  \
# Respondent
# 4                                          Employed full-time  United States
# 13                                         Employed full-time  United States
# 22                                         Employed full-time  United States
# 23                                         Employed full-time  United States
# 26                                         Employed full-time  United States
# ...                                                       ...            ...
# 78292       Independent contractor, freelancer, or self-em...  United States
# 82717                      Not employed, but looking for work  United States
# 83397                      Not employed, but looking for work  United States
# 85642       Independent contractor, freelancer, or self-em...  United States
# 88282                      Not employed, but looking for work  United States
#
#            Student                                            EdLevel  \
# Respondent
# 4               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 13              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 22              No  Some college/university study without earning ...
# 23              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 26              No  Some college/university study without earning ...
# ...            ...                                                ...
# 78292           No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 82717           No  Secondary school (e.g. American high school, G...
# 83397           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 85642           No                                   Associate degree
# 88282           No  Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 4           Computer science, computer engineering, or sof...
# 13          Computer science, computer engineering, or sof...
# 22                                                        NaN
# 23          Information systems, information technology, o...
# 26          Computer science, computer engineering, or sof...
# ...                                                       ...
# 78292       A health science (ex. nursing, pharmacy, radio...
# 82717                                                     NaN
# 83397       Computer science, computer engineering, or sof...
# 85642       Information systems, information technology, o...
# 88282       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 4           Taken an online course in programming or softw...
# 13          Taken an online course in programming or softw...
# 22          Taken an online course in programming or softw...
# 23          Taken an online course in programming or softw...
# 26          Taught yourself a new language, framework, or ...
# ...                                                       ...
# 78292       Completed an industry certification program (e...
# 82717                                                     NaN
# 83397       Taken an online course in programming or softw...
# 85642       Taken an online course in programming or softw...
# 88282       Taught yourself a new language, framework, or ...
#
#                                                       OrgSize  \
# Respondent
# 4                                        100 to 499 employees
# 13                                         10 to 19 employees
# 22                                   10,000 or more employees
# 23                                   10,000 or more employees
# 26                                   10,000 or more employees
# ...                                                       ...
# 78292       Just me - I am a freelancer, sole proprietor, ...
# 82717                                                     NaN
# 83397                                                     NaN
# 85642       Just me - I am a freelancer, sole proprietor, ...
# 88282                                                     NaN
#
#                                                       DevType  \
# Respondent
# 4                                       Developer, full-stack
# 13          Data or business analyst;Database administrato...
# 22          Data or business analyst;Designer;Developer, b...
# 23                                      Developer, full-stack
# 26          Designer;Developer, back-end;Developer, deskto...
# ...                                                       ...
# 78292                                     Academic researcher
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                Designer;Marketing or sales professional
# 88282       Developer, back-end;Developer, desktop or ente...
#
#                    YearsCode Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 4                          3         16  Less than 1 year      Very satisfied
# 13                        17         11                 8      Very satisfied
# 22                        35         12                18  Slightly satisfied
# 23                         3         19                 1  Slightly satisfied
# 26                        12          8                 8      Very satisfied
# ...                      ...        ...               ...                 ...
# 78292                     42         14                31                 NaN
# 82717       Less than 1 year        NaN  Less than 1 year                 NaN
# 83397                     12          9  Less than 1 year                 NaN
# 85642                     20          7  Less than 1 year                 NaN
# 88282                     38         10                38                 NaN
#
#                         JobSat            MgrIdiot MgrMoney   MgrWant  \
# Respondent
# 4           Slightly satisfied      Very confident       No  Not sure
# 13              Very satisfied                 NaN      NaN       NaN
# 22           Very dissatisfied  Somewhat confident       No        No
# 23          Slightly satisfied      Very confident       No  Not sure
# 26              Very satisfied                 NaN      NaN       NaN
# ...                        ...                 ...      ...       ...
# 78292                      NaN                 NaN      NaN       NaN
# 82717                      NaN                 NaN      NaN       NaN
# 83397                      NaN                 NaN      NaN       NaN
# 85642                      NaN                 NaN      NaN       NaN
# 88282                      NaN                 NaN      NaN       NaN
#
#                                                       JobSeek  \
# Respondent
# 4                I am not interested in new job opportunities
# 13               I am not interested in new job opportunities
# 22          I’m not actively looking, but I am open to new...
# 23          I’m not actively looking, but I am open to new...
# 26          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                      LastHireDate  \
# Respondent
# 4            Less than a year ago
# 13                  3-4 years ago
# 22          More than 4 years ago
# 23           Less than a year ago
# 26           Less than a year ago
# ...                           ...
# 78292                         NaN
# 82717                         NaN
# 83397                         NaN
# 85642                         NaN
# 88282                         NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 13          Complete a take-home project;Interview with pe...      Yes
# 22          Interview with people in senior / management r...       No
# 23          Write any code;Write code by hand (e.g., on a ...       No
# 26          Interview with people in peer roles;Interview ...       No
# ...                                                       ...      ...
# 78292                                                     NaN      NaN
# 82717                                                     NaN      NaN
# 83397                                                     NaN      NaN
# 85642                                                     NaN      NaN
# 88282                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 4           Languages, frameworks, and other technologies ...
# 13          Languages, frameworks, and other technologies ...
# 22          Industry that I'd be working in;Financial perf...
# 23          Opportunities for professional development;How...
# 26          Remote work options;Diversity of the company o...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 4                            I was preparing for a job search            USD
# 13                           I was preparing for a job search            USD
# 22          I had a negative experience or interaction at ...            USD
# 23                           I was preparing for a job search            USD
# 26                           I was preparing for a job search            USD
# ...                                                       ...            ...
# 78292                                                     NaN            NaN
# 82717                                                     NaN            NaN
# 83397                                                     NaN            NaN
# 85642                                                     NaN            NaN
# 88282                                                     NaN            NaN
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 4           United States dollar    61000.0   Yearly        61000.0
# 13          United States dollar    90000.0   Yearly        90000.0
# 22          United States dollar   103000.0   Yearly       103000.0
# 23          United States dollar    69000.0   Yearly        69000.0
# 26          United States dollar   114000.0   Yearly       114000.0
# ...                          ...        ...      ...            ...
# 78292                        NaN        NaN      NaN            NaN
# 82717                        NaN        NaN      NaN            NaN
# 83397                        NaN        NaN      NaN            NaN
# 85642                        NaN        NaN      NaN            NaN
# 88282                        NaN        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 4                  80.0  There's no schedule or spec; I work on what se...
# 13                 40.0  There is a schedule and/or spec (made by me or...
# 22                 40.0  There is a schedule and/or spec (made by me or...
# 23                 40.0  There is a schedule and/or spec (made by me or...
# 26                 40.0  There is a schedule and/or spec (made by me or...
# ...                 ...                                                ...
# 78292               NaN                                                NaN
# 82717               NaN                                                NaN
# 83397               NaN                                                NaN
# 85642               NaN                                                NaN
# 88282               NaN                                                NaN
#
#                                                 WorkChallenge  \
# Respondent
# 4                                                         NaN
# 13          Meetings;Non-work commitments (parenting, scho...
# 22          Being tasked with non-development work;Meeting...
# 23          Distracting work environment;Meetings;Non-work...
# 26          Being tasked with non-development work;Meeting...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 4                            Less than once per month / Never    Home
# 13          All or almost all the time (I'm full-time remote)    Home
# 22          Less than half the time, but at least one day ...    Home
# 23                                      A few days each month  Office
# 26          Less than half the time, but at least one day ...    Home
# ...                                                       ...     ...
# 78292                                                     NaN     NaN
# 82717                                                     NaN     NaN
# 83397                                                     NaN     NaN
# 85642                                                     NaN     NaN
# 88282                                                     NaN     NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 4           A little below average                                       No
# 13          A little above average  Yes, because I see value in code review
# 22                         Average                                       No
# 23                         Average  Yes, because I see value in code review
# 26               Far above average  Yes, because I see value in code review
# ...                            ...                                      ...
# 78292                          NaN                                      NaN
# 82717                          NaN                                      NaN
# 83397                          NaN                                      NaN
# 85642                          NaN                                      NaN
# 88282                          NaN                                      NaN
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 4                  NaN                          No, but I think we should
# 13                 5.0                          No, but I think we should
# 22                 NaN                          No, but I think we should
# 23                 8.0                      Yes, it's part of our process
# 26                 2.0  Yes, it's not part of our process but the deve...
# ...                ...                                                ...
# 78292              NaN                                                NaN
# 82717              NaN                                                NaN
# 83397              NaN                                                NaN
# 85642              NaN                                                NaN
# 88282              NaN                                                NaN
#
#                                                   PurchaseHow  \
# Respondent
# 4           Developers typically have the most influence o...
# 13          Developers and management have nearly equal in...
# 22          The CTO, CIO, or other management purchase new...
# 23          Developers and management have nearly equal in...
# 26          Developers typically have the most influence o...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642                                                     NaN
# 88282                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 4              I have little or no influence
# 13          I have a great deal of influence
# 22             I have little or no influence
# 23             I have little or no influence
# 26          I have a great deal of influence
# ...                                      ...
# 78292                                    NaN
# 82717                                    NaN
# 83397                                    NaN
# 85642                                    NaN
# 88282                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 4                                         C;C++;C#;Python;SQL
# 13          Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 23          Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 26          Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# ...                                                       ...
# 78292                          Bash/Shell/PowerShell;C;Python
# 82717                                                     NaN
# 83397                          HTML/CSS;JavaScript;Python;SQL
# 85642                                             Go;HTML/CSS
# 88282       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 4                                         C;C#;JavaScript;SQL
# 13          Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 23          Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 26          C#;HTML/CSS;JavaScript;Objective-C;Ruby;SQL;Sw...
# ...                                                       ...
# 78292                          Bash/Shell/PowerShell;C;Python
# 82717                                                     NaN
# 83397       C;C++;C#;Go;Java;JavaScript;Python;R;Ruby;SQL;...
# 85642                                                     NaN
# 88282       Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
#
#                                  DatabaseWorkedWith  \
# Respondent
# 4                                      MySQL;SQLite
# 13                Couchbase;DynamoDB;Firebase;MySQL
# 22                 Elasticsearch;MySQL;Oracle;Redis
# 23                                    Oracle;SQLite
# 26          Microsoft SQL Server;MySQL;Redis;SQLite
# ...                                             ...
# 78292                                        SQLite
# 82717                                           NaN
# 83397                                           NaN
# 85642                                           NaN
# 88282                                           NaN
#
#                                       DatabaseDesireNextYear  \
# Respondent
# 4                                               MySQL;SQLite
# 13                                      Firebase;MySQL;Redis
# 22                          Elasticsearch;MySQL;Oracle;Redis
# 23          Couchbase;DynamoDB;Elasticsearch;Firebase;Oracle
# 26                   Microsoft SQL Server;MySQL;Redis;SQLite
# ...                                                      ...
# 78292                                                 SQLite
# 82717                                                    NaN
# 83397                                                    NaN
# 85642                                                    NaN
# 88282                                                    NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 4                                               Linux;Windows
# 13          Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 22                          Docker;Linux;Raspberry Pi;Windows
# 23                               Docker;Google Cloud Platform
# 26          AWS;Docker;Linux;MacOS;Microsoft Azure;Windows...
# ...                                                       ...
# 78292                            Linux;Raspberry Pi;Other(s):
# 82717                                         Android;Windows
# 83397                                   Android;Arduino;Slack
# 85642                                                     NaN
# 88282                                                   Linux
#
#                                        PlatformDesireNextYear  \
# Respondent
# 4                                               Linux;Windows
# 13          Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# 22                          Docker;Linux;Raspberry Pi;Windows
# 23                                           Docker;iOS;Slack
# 26          Android;Docker;iOS;Linux;MacOS;Microsoft Azure...
# ...                                                       ...
# 78292                            Linux;Raspberry Pi;Other(s):
# 82717                         Android;Microsoft Azure;Windows
# 83397           Android;Arduino;Docker;iOS;Raspberry Pi;Slack
# 85642                                                     NaN
# 88282                                      Linux;Raspberry Pi
#
#                                            WebFrameWorkedWith  \
# Respondent
# 4                                                         NaN
# 13           Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# 22                           Angular/Angular.js;Ruby on Rails
# 23                                     React.js;Ruby on Rails
# 26          Angular/Angular.js;ASP.NET;Drupal;Express;jQue...
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                   Flask
# 85642                                                     NaN
# 88282                                                React.js
#
#                            WebFrameDesireNextYear  \
# Respondent
# 4                                             NaN
# 13                                 Express;Vue.js
# 22               Angular/Angular.js;Ruby on Rails
# 23          Express;React.js;Ruby on Rails;Vue.js
# 26                     Angular/Angular.js;ASP.NET
# ...                                           ...
# 78292                                         NaN
# 82717                                         NaN
# 83397         Django;Drupal;Flask;jQuery;React.js
# 85642                                         NaN
# 88282                                      Vue.js
#
#                         MiscTechWorkedWith   MiscTechDesireNextYear  \
# Respondent
# 4                                     .NET                     .NET
# 13                         Node.js;Xamarin       Node.js;TensorFlow
# 22                                 Node.js                  Node.js
# 23                                     NaN  React Native;TensorFlow
# 26          .NET;.NET Core;Node.js;Xamarin   .NET;.NET Core;Node.js
# ...                                    ...                      ...
# 78292                                 Chef                      NaN
# 82717                                  NaN                      NaN
# 83397                                  NaN       Chef;Torch/PyTorch
# 85642                                  NaN                      NaN
# 88282                              Node.js                  Ansible
#
#                                                 DevEnviron        OpSys  \
# Respondent
# 4             Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 13              Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# 22           Sublime Text;Visual Studio;Visual Studio Code      Windows
# 23                                      Visual Studio Code        MacOS
# 26          Notepad++;Sublime Text;Vim;Visual Studio;Xcode        MacOS
# ...                                                    ...          ...
# 78292                              Emacs;IPython / Jupyter  Linux-based
# 82717                                                  NaN        MacOS
# 83397               Eclipse;IPython / Jupyter;Sublime Text        MacOS
# 85642                                   Visual Studio Code      Windows
# 88282                                                  Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 4                          I do not use containers    Not at all
# 13                  Development;Testing;Production    Not at all
# 22          Outside of work, for personal projects    Not at all
# 23                  Development;Testing;Production           NaN
# 26                             Development;Testing    Not at all
# ...                                            ...           ...
# 78292                      I do not use containers           NaN
# 82717                                      Testing           NaN
# 83397                      I do not use containers           NaN
# 85642                      I do not use containers           NaN
# 88282                      I do not use containers           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 13          Useful for decentralized currency (i.e., Bitcoin)        Yes
# 22                                                        NaN        Yes
# 23          Useful for immutable record keeping outside of...        Yes
# 26                                              A passing fad        Yes
# ...                                                       ...        ...
# 78292       Useful for immutable record keeping outside of...         No
# 82717                                                     NaN         No
# 83397                                                     NaN        NaN
# 85642       Useful for immutable record keeping outside of...         No
# 88282                       An irresponsible use of resources         No
#
#            ITperson OffOn               SocialMedia              Extraversion  \
# Respondent
# 4              SIGH   Yes                    Reddit  In real life (in person)
# 13              Yes   Yes                   Twitter  In real life (in person)
# 22              Yes   Yes                 Instagram                    Online
# 23             SIGH   Yes                    Reddit  In real life (in person)
# 26             SIGH   Yes  I don't use social media  In real life (in person)
# ...             ...   ...                       ...                       ...
# 78292           Yes   Yes  I don't use social media  In real life (in person)
# 82717          SIGH   Yes                  Facebook  In real life (in person)
# 83397          SIGH   Yes                       NaN                       NaN
# 85642          SIGH   Yes                       NaN  In real life (in person)
# 88282           NaN   Yes  I don't use social media  In real life (in person)
#
#            ScreenName        SOVisit1st                          SOVisitFreq  \
# Respondent
# 4            Username              2014                Daily or almost daily
# 13           Username              2011               Multiple times per day
# 22           Username  I don't remember                Daily or almost daily
# 23           Username              2014               Multiple times per day
# 26           Username              2008                Daily or almost daily
# ...               ...               ...                                  ...
# 78292             NaN              2013                 A few times per week
# 82717        Username              2018  Less than once per month or monthly
# 83397          Handle  I don't remember                 A few times per week
# 85642          Handle              2008  Less than once per month or monthly
# 88282        Username  I don't remember      A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 4           Find answers to specific questions;Pass the ti...
# 13                         Find answers to specific questions
# 22                         Find answers to specific questions
# 23          Find answers to specific questions;Learn how t...
# 26          Find answers to specific questions;Learn how t...
# ...                                                       ...
# 78292                      Find answers to specific questions
# 82717                      Find answers to specific questions
# 83397       Find answers to specific questions;Learn how t...
# 85642                      Find answers to specific questions
# 88282                      Find answers to specific questions
#
#                            SOFindAnswer  \
# Respondent
# 4                    1-2 times per week
# 13          More than 10 times per week
# 22                   3-5 times per week
# 23                  6-10 times per week
# 26                   3-5 times per week
# ...                                 ...
# 78292           Less than once per week
# 82717           Less than once per week
# 83397                3-5 times per week
# 85642           Less than once per week
# 88282                1-2 times per week
#
#                                        SOTimeSaved  SOHowMuchTime  \
# Respondent
# 4                   Stack Overflow was much faster  31-60 minutes
# 13                  Stack Overflow was much faster  11-30 minutes
# 22                  Stack Overflow was much faster   0-10 minutes
# 23                        They were about the same            NaN
# 26                  Stack Overflow was much faster  11-30 minutes
# ...                                            ...            ...
# 78292       The other resource was slightly faster  11-30 minutes
# 82717                                          NaN    60+ minutes
# 83397                     They were about the same            NaN
# 85642           Stack Overflow was slightly faster    60+ minutes
# 88282                     They were about the same            NaN
#
#                             SOAccount  \
# Respondent
# 4                                 Yes
# 13                                Yes
# 22                                Yes
# 23                                Yes
# 26                                Yes
# ...                               ...
# 78292       Not sure / can't remember
# 82717                              No
# 83397       Not sure / can't remember
# 85642                             Yes
# 88282                             Yes
#
#                                                    SOPartFreq  \
# Respondent
# 4                         Less than once per month or monthly
# 13                        Less than once per month or monthly
# 22                                       A few times per week
# 23          I have never participated in Q&A on Stack Over...
# 26                        Less than once per month or monthly
# ...                                                       ...
# 78292                                                     NaN
# 82717                                                     NaN
# 83397                                                     NaN
# 85642       I have never participated in Q&A on Stack Over...
# 88282       I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 4                                                         Yes
# 13                                                        Yes
# 22                                                        Yes
# 23                                                        Yes
# 26                                                        Yes
# ...                                                       ...
# 78292       No, I didn't know that Stack Overflow had a jo...
# 82717       No, I knew that Stack Overflow had a job board...
# 83397                                                     Yes
# 85642       No, I knew that Stack Overflow had a job board...
# 88282                                                     Yes
#
#                                                      EntTeams          SOComm  \
# Respondent
# 4                         No, and I don't know what those are  No, not really
# 13          No, I've heard of them, but I am not part of a...         Neutral
# 22                        No, and I don't know what those are   Yes, somewhat
# 23          No, I've heard of them, but I am not part of a...  No, not really
# 26          No, I've heard of them, but I am not part of a...         Neutral
# ...                                                       ...             ...
# 78292                     No, and I don't know what those are  No, not really
# 82717       No, I've heard of them, but I am not part of a...        Not sure
# 83397                     No, and I don't know what those are  No, not at all
# 85642                     No, and I don't know what those are  No, not at all
# 88282                     No, and I don't know what those are  No, not really
#
#                                        WelcomeChange  \
# Respondent
# 4            Just as welcome now as I felt last year
# 13          Somewhat more welcome now than last year
# 22           Just as welcome now as I felt last year
# 23           Just as welcome now as I felt last year
# 26           Just as welcome now as I felt last year
# ...                                              ...
# 78292       Somewhat less welcome now than last year
# 82717                                            NaN
# 83397        Just as welcome now as I felt last year
# 85642        Just as welcome now as I felt last year
# 88282        Just as welcome now as I felt last year
#
#                                                  SONewContent   Age  \
# Respondent
# 4           Tech articles written by other developers;Indu...  22.0
# 13          Tech articles written by other developers;Cour...  28.0
# 22          Tech articles written by other developers;Indu...  47.0
# 23          Tech articles written by other developers;Tech...  22.0
# 26                                                        NaN  34.0
# ...                                                       ...   ...
# 78292                                                     NaN  60.0
# 82717       Industry news about technologies you're intere...  44.0
# 83397                                                     NaN  27.0
# 85642       Tech articles written by other developers;Indu...  34.0
# 88282                                                     NaN   NaN
#
#                                                        Gender Trans  \
# Respondent
# 4                                                         Man    No
# 13                                                        Man    No
# 22                                                        Man    No
# 23                                                        Man    No
# 26                                                        Man    No
# ...                                                       ...   ...
# 78292                                                     Man    No
# 82717                                                     Man    No
# 83397                                                   Woman    No
# 85642       Non-binary, genderqueer, or gender non-conforming   NaN
# 88282                                                     Man    No
#
#                           Sexuality                     Ethnicity Dependents  \
# Respondent
# 4           Straight / Heterosexual  White or of European descent         No
# 13          Straight / Heterosexual  White or of European descent        Yes
# 22          Straight / Heterosexual  White or of European descent        Yes
# 23          Straight / Heterosexual   Black or of African descent         No
# 26                   Gay or Lesbian                           NaN         No
# ...                             ...                           ...        ...
# 78292       Straight / Heterosexual  White or of European descent        Yes
# 82717       Straight / Heterosexual  White or of European descent        Yes
# 83397                      Bisexual  White or of European descent         No
# 85642       Bisexual;Gay or Lesbian  White or of European descent         No
# 88282       Straight / Heterosexual                           NaN         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 4           Appropriate in length                        Easy
# 13          Appropriate in length                        Easy
# 22          Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 26          Appropriate in length                        Easy
# ...                           ...                         ...
# 78292                    Too long  Neither easy nor difficult
# 82717       Appropriate in length  Neither easy nor difficult
# 83397       Appropriate in length                        Easy
# 85642       Appropriate in length                        Easy
# 88282                   Too short  Neither easy nor difficult
#
# [20949 rows x 84 columns]

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(100)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                     15
#              YouTube                       9
#              I don't use social media      6
#              WhatsApp                      4
#              Instagram                     1
#                                         ...
# Bangladesh   Facebook                    313
#              YouTube                     137
#              LinkedIn                     62
#              Twitter                      19
#              I don't use social media     17
# Name: SocialMedia, Length: 100, dtype: int64

# %%
country_grp.get_group('Philippines')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 71                  I am a developer by profession      Yes
# 940         I am a student who is learning to code      Yes
# 1003                   I code primarily as a hobby      Yes
# 1216                I am a developer by profession      Yes
# 1338                I am a developer by profession      Yes
# ...                                            ...      ...
# 88677               I am a developer by profession      Yes
# 27544                                          NaN      Yes
# 29998                                          NaN      Yes
# 44923                                          NaN       No
# 76444                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 71                                                      Never
# 940                                   Less than once per year
# 1003                                                    Never
# 1216        Less than once a month but more than once per ...
# 1338                                                    Never
# ...                                                       ...
# 88677                                                   Never
# 27544                              Once a month or more often
# 29998       Less than once a month but more than once per ...
# 44923                              Once a month or more often
# 76444                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 71          The quality of OSS and closed source software ...
# 940         OSS is, on average, of HIGHER quality than pro...
# 1003        OSS is, on average, of HIGHER quality than pro...
# 1216        OSS is, on average, of LOWER quality than prop...
# 1338        OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 88677       The quality of OSS and closed source software ...
# 27544       OSS is, on average, of LOWER quality than prop...
# 29998       OSS is, on average, of LOWER quality than prop...
# 44923       OSS is, on average, of HIGHER quality than pro...
# 76444       OSS is, on average, of LOWER quality than prop...
#
#                                                    Employment      Country  \
# Respondent
# 71                                         Employed full-time  Philippines
# 940                                                       NaN  Philippines
# 1003                       Not employed, but looking for work  Philippines
# 1216                                       Employed full-time  Philippines
# 1338                                       Employed full-time  Philippines
# ...                                                       ...          ...
# 88677                                      Employed full-time  Philippines
# 27544                                      Employed part-time  Philippines
# 29998                                      Employed full-time  Philippines
# 44923       Independent contractor, freelancer, or self-em...  Philippines
# 76444                                      Employed full-time  Philippines
#
#                    Student                                            EdLevel  \
# Respondent
# 71                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 940         Yes, part-time  Some college/university study without earning ...
# 1003        Yes, full-time  Secondary school (e.g. American high school, G...
# 1216                    No  Some college/university study without earning ...
# 1338                    No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                                ...
# 88677                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 27544                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 29998                   No                          Primary/elementary school
# 44923                   No  Some college/university study without earning ...
# 76444       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 71          Computer science, computer engineering, or sof...
# 940         Computer science, computer engineering, or sof...
# 1003                                                      NaN
# 1216        Information systems, information technology, o...
# 1338                            Web development or web design
# ...                                                       ...
# 88677       Computer science, computer engineering, or sof...
# 27544       Computer science, computer engineering, or sof...
# 29998                                                     NaN
# 44923       Another engineering discipline (ex. civil, ele...
# 76444                                I never declared a major
#
#                                                      EduOther  \
# Respondent
# 71          Received on-the-job training in software devel...
# 940         Taken an online course in programming or softw...
# 1003        Taken an online course in programming or softw...
# 1216        Completed an industry certification program (e...
# 1338        Taken an online course in programming or softw...
# ...                                                       ...
# 88677       Taught yourself a new language, framework, or ...
# 27544                                                     NaN
# 29998       Taken an online course in programming or softw...
# 44923       Received on-the-job training in software devel...
# 76444       Participated in online coding competitions (e....
#
#                          OrgSize  \
# Respondent
# 71            20 to 99 employees
# 940                          NaN
# 1003                         NaN
# 1216          20 to 99 employees
# 1338                         NaN
# ...                          ...
# 88677       100 to 499 employees
# 27544         20 to 99 employees
# 29998              2-9 employees
# 44923       500 to 999 employees
# 76444                        NaN
#
#                                                       DevType  \
# Respondent
# 71                                      Developer, full-stack
# 940                                                       NaN
# 1003        Designer;Developer, back-end;Developer, deskto...
# 1216        Developer, front-end;Developer, full-stack;Dev...
# 1338        Designer;Developer, back-end;Developer, front-end
# ...                                                       ...
# 88677       Developer, back-end;Developer, desktop or ente...
# 27544                                                     NaN
# 29998       Data or business analyst;Developer, desktop or...
# 44923                         Marketing or sales professional
# 76444       Developer, back-end;Developer, desktop or ente...
#
#                    YearsCode            Age1stCode      YearsCodePro  \
# Respondent
# 71                         4                    17  Less than 1 year
# 940                        3                    16               NaN
# 1003                       3                    16               NaN
# 1216                       6                    18                 4
# 1338                       5                    17  Less than 1 year
# ...                      ...                   ...               ...
# 88677                     12                    17                 8
# 27544                      1                   NaN                 1
# 29998       Less than 1 year  Younger than 5 years                 5
# 44923       Less than 1 year                    25                 2
# 76444                      3                    10  Less than 1 year
#
#                      CareerSat                 JobSat                MgrIdiot  \
# Respondent
# 71              Very satisfied     Slightly satisfied          Very confident
# 940                        NaN                    NaN                     NaN
# 1003                       NaN                    NaN                     NaN
# 1216        Slightly satisfied  Slightly dissatisfied      Somewhat confident
# 1338            Very satisfied         Very satisfied          Very confident
# ...                        ...                    ...                     ...
# 88677       Slightly satisfied         Very satisfied          Very confident
# 27544                      NaN                    NaN    Not at all confident
# 29998                      NaN                    NaN  I don't have a manager
# 44923                      NaN                    NaN                     NaN
# 76444                      NaN                    NaN  I don't have a manager
#
#             MgrMoney                 MgrWant  \
# Respondent
# 71                No                Not sure
# 940              NaN                     NaN
# 1003             NaN                     NaN
# 1216              No                Not sure
# 1338        Not sure                     Yes
# ...              ...                     ...
# 88677             No                      No
# 27544            Yes                Not sure
# 29998             No  I am already a manager
# 44923            NaN                     NaN
# 76444       Not sure                      No
#
#                                                       JobSeek  \
# Respondent
# 71          I’m not actively looking, but I am open to new...
# 940                           I am actively looking for a job
# 1003                                                      NaN
# 1216        I’m not actively looking, but I am open to new...
# 1338        I’m not actively looking, but I am open to new...
# ...                                                       ...
# 88677            I am not interested in new job opportunities
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 71          Less than a year ago
# 940         Less than a year ago
# 1003                         NaN
# 1216               1-2 years ago
# 1338        Less than a year ago
# ...                          ...
# 88677              3-4 years ago
# 27544                        NaN
# 29998                        NaN
# 44923                        NaN
# 76444                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 71                        Interview with people in peer roles       No
# 940                                                       NaN      NaN
# 1003                                                      NaN      NaN
# 1216        Solve a brain-teaser style puzzle;Interview wi...       No
# 1338        Write code by hand (e.g., on a whiteboard);Sol...       No
# ...                                                       ...      ...
# 88677       Write code by hand (e.g., on a whiteboard);Int...       No
# 27544                                                     NaN      NaN
# 29998                                                     NaN      NaN
# 44923                                                     NaN      NaN
# 76444                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 71          Languages, frameworks, and other technologies ...
# 940         Office environment or company culture;Opportun...
# 1003                                                      NaN
# 1216        Languages, frameworks, and other technologies ...
# 1338        Office environment or company culture;Opportun...
# ...                                                       ...
# 88677       Remote work options;Opportunities for professi...
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 71                           I was preparing for a job search            PHP
# 940                          I was preparing for a job search            NaN
# 1003                                                      NaN            NaN
# 1216                         I was preparing for a job search            PHP
# 1338        Something else changed (education, award, medi...            PHP
# ...                                                       ...            ...
# 88677                        I was preparing for a job search            PHP
# 27544                                                     NaN            NaN
# 29998                                                     NaN            NaN
# 44923                                                     NaN            NaN
# 76444                                                     NaN            NaN
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 71          Philippine peso    18000.0  Monthly         4128.0          8.0
# 940                     NaN        NaN      NaN            NaN          NaN
# 1003                    NaN        NaN      NaN            NaN          NaN
# 1216        Philippine peso        NaN      NaN            NaN         42.5
# 1338        Philippine peso        NaN      NaN            NaN          NaN
# ...                     ...        ...      ...            ...          ...
# 88677       Philippine peso        NaN      NaN            NaN          NaN
# 27544                   NaN        NaN      NaN            NaN          NaN
# 29998                   NaN        NaN      NaN            NaN          NaN
# 44923                   NaN        NaN      NaN            NaN          NaN
# 76444                   NaN        NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 71          There is a schedule and/or spec (made by me or...
# 940                                                       NaN
# 1003                                                      NaN
# 1216        There is a schedule and/or spec (made by me or...
# 1338        There is a schedule and/or spec (made by me or...
# ...                                                       ...
# 88677       There's no schedule or spec; I work on what se...
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                                                     NaN
#
#                                                 WorkChallenge  \
# Respondent
# 71          Distracting work environment;Not enough people...
# 940                                                       NaN
# 1003                                                      NaN
# 1216                                     Time spent commuting
# 1338        Distracting work environment;Time spent commut...
# ...                                                       ...
# 88677       Being tasked with non-development work;Distrac...
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                                                     NaN
#
#                                   WorkRemote  \
# Respondent
# 71                     A few days each month
# 940                                      NaN
# 1003                                     NaN
# 1216        Less than once per month / Never
# 1338                                     NaN
# ...                                      ...
# 88677                  A few days each month
# 27544                                    NaN
# 29998                                    NaN
# 44923                                    NaN
# 76444                                    NaN
#
#                                                    WorkLoc  \
# Respondent
# 71                                                  Office
# 940                                                    NaN
# 1003                                                   NaN
# 1216                                                Office
# 1338        Other place, such as a coworking space or cafe
# ...                                                    ...
# 88677                                                 Home
# 27544                                                  NaN
# 29998                                                  NaN
# 44923                                                  NaN
# 76444                                                  NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 71          A little above average                                       No
# 940                            NaN                                      NaN
# 1003                           NaN                                      NaN
# 1216        A little above average  Yes, because I see value in code review
# 1338                       Average  Yes, because I see value in code review
# ...                            ...                                      ...
# 88677            Far above average  Yes, because I see value in code review
# 27544                          NaN                                      NaN
# 29998                          NaN                                      NaN
# 44923                          NaN                                      NaN
# 76444                          NaN                                      NaN
#
#             CodeRevHrs                      UnitTests  \
# Respondent
# 71                 NaN      No, but I think we should
# 940                NaN                            NaN
# 1003               NaN                            NaN
# 1216               6.0      No, but I think we should
# 1338               NaN  Yes, it's part of our process
# ...                ...                            ...
# 88677              NaN      No, but I think we should
# 27544              NaN                            NaN
# 29998              NaN                            NaN
# 44923              NaN                            NaN
# 76444              NaN                            NaN
#
#                                                   PurchaseHow  \
# Respondent
# 71          The CTO, CIO, or other management purchase new...
# 940                                                       NaN
# 1003                                                      NaN
# 1216                                                 Not sure
# 1338        Developers and management have nearly equal in...
# ...                                                       ...
# 88677       Developers and management have nearly equal in...
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 71                     I have some influence
# 940                                      NaN
# 1003                                     NaN
# 1216           I have little or no influence
# 1338                   I have some influence
# ...                                      ...
# 88677       I have a great deal of influence
# 27544                                    NaN
# 29998                                    NaN
# 44923                                    NaN
# 76444                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 71                     HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 940                                     HTML/CSS;Java;PHP;SQL
# 1003                  C++;C#;HTML/CSS;Java;JavaScript;PHP;SQL
# 1216                          C++;C#;HTML/CSS;Java;JavaScript
# 1338                          C++;HTML/CSS;JavaScript;PHP;SQL
# ...                                                       ...
# 88677       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# 27544                                                     NaN
# 29998                                              JavaScript
# 44923                                                     NaN
# 76444                                                HTML/CSS
#
#                                        LanguageDesireNextYear  \
# Respondent
# 71                        C#;HTML/CSS;JavaScript;PHP;Ruby;SQL
# 940                                       C++;C#;Java;PHP;SQL
# 1003                                                      NaN
# 1216                                                       C#
# 1338                             HTML/CSS;Java;JavaScript;SQL
# ...                                                       ...
# 88677       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# 27544                                     Assembly;JavaScript
# 29998                                 Assembly;Java;Other(s):
# 44923                                                     PHP
# 76444                                                Assembly
#
#                                 DatabaseWorkedWith  \
# Respondent
# 71                                   MariaDB;MySQL
# 940              Microsoft SQL Server;MySQL;SQLite
# 1003                    Microsoft SQL Server;MySQL
# 1216                                  MySQL;SQLite
# 1338                                         MySQL
# ...                                            ...
# 88677       Microsoft SQL Server;PostgreSQL;SQLite
# 27544                                          NaN
# 29998                                          NaN
# 44923                                          NaN
# 76444                         Microsoft SQL Server
#
#                             DatabaseDesireNextYear  \
# Respondent
# 71                            DynamoDB;MySQL;Redis
# 940                                         Oracle
# 1003                                           NaN
# 1216                                        SQLite
# 1338             Microsoft SQL Server;MySQL;Oracle
# ...                                            ...
# 88677       Microsoft SQL Server;PostgreSQL;SQLite
# 27544                         Microsoft SQL Server
# 29998                                          NaN
# 44923                                    Other(s):
# 76444                         Microsoft SQL Server
#
#                                            PlatformWorkedWith  \
# Respondent
# 71          Android;Arduino;AWS;Linux;MacOS;Raspberry Pi;W...
# 940                                           Android;Windows
# 1003                                                      NaN
# 1216                        Android;Google Cloud Platform;iOS
# 1338                                                  Windows
# ...                                                       ...
# 88677       AWS;Google Cloud Platform;Heroku;Microsoft Azu...
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                               Google Cloud Platform;iOS
#
#                                        PlatformDesireNextYear  \
# Respondent
# 71                              Android;AWS;iOS;MacOS;Windows
# 940                                                   Windows
# 1003                                                      NaN
# 1216                        Android;Google Cloud Platform;iOS
# 1338                Android;Arduino;iOS;Linux;MacOS;WordPress
# ...                                                       ...
# 88677       Android;Arduino;AWS;Google Cloud Platform;Hero...
# 27544                           Android;Google Cloud Platform
# 29998                                                 Android
# 44923                                                 Android
# 76444                               Google Cloud Platform;iOS
#
#                                    WebFrameWorkedWith  \
# Respondent
# 71                                   Laravel;React.js
# 940                                    ASP.NET;jQuery
# 1003                                          Laravel
# 1216                                           jQuery
# 1338                                           jQuery
# ...                                               ...
# 88677       Angular/Angular.js;ASP.NET;Express;jQuery
# 27544                                             NaN
# 29998                                             NaN
# 44923                                             NaN
# 76444                                             NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 71          Angular/Angular.js;Django;jQuery;Laravel;React...
# 940                                            ASP.NET;jQuery
# 1003                                                  Laravel
# 1216                                                      NaN
# 1338                           ASP.NET;Drupal;jQuery;React.js
# ...                                                       ...
# 88677       Angular/Angular.js;ASP.NET;Express;jQuery;Reac...
# 27544                                               Other(s):
# 29998                                                     NaN
# 44923                                               Other(s):
# 76444                                                     NaN
#
#                          MiscTechWorkedWith  \
# Respondent
# 71                         Node.js;Unity 3D
# 940                                    .NET
# 1003                         .NET;.NET Core
# 1216        .NET;.NET Core;Unity 3D;Xamarin
# 1338                                   .NET
# ...                                     ...
# 88677                          .NET;Node.js
# 27544                                   NaN
# 29998                                   NaN
# 44923                                   NaN
# 76444                                   NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 71                                       Node.js;React Native
# 940                                                      .NET
# 1003                                                      NaN
# 1216                                   .NET;.NET Core;Xamarin
# 1338                                             .NET;Node.js
# ...                                                       ...
# 88677       Cordova;.NET;.NET Core;Node.js;React Native;Xa...
# 27544                                                    .NET
# 29998                                                     NaN
# 44923                                               Other(s):
# 76444                                                     NaN
#
#                                                    DevEnviron    OpSys  \
# Respondent
# 71                                         Visual Studio Code    MacOS
# 940         Android Studio;NetBeans;Notepad++;Sublime Text...  Windows
# 1003                         Visual Studio;Visual Studio Code  Windows
# 1216          Android Studio;Sublime Text;Visual Studio;Xcode    MacOS
# 1338                                             Sublime Text  Windows
# ...                                                       ...      ...
# 88677       Notepad++;Sublime Text;Visual Studio;Visual St...  Windows
# 27544                                          Android Studio  Windows
# 29998                                          Android Studio  Windows
# 44923                                               Notepad++  Windows
# 76444                                          Android Studio  Windows
#
#                          Containers  \
# Respondent
# 71          I do not use containers
# 940                     Development
# 1003        I do not use containers
# 1216        I do not use containers
# 1338                    Development
# ...                             ...
# 88677       I do not use containers
# 27544       I do not use containers
# 29998                   Development
# 44923       I do not use containers
# 76444                   Development
#
#                                                 BlockchainOrg  \
# Respondent
# 71          Accepting Bitcoin or other coins and tokens as...
# 940                                                       NaN
# 1003                                                      NaN
# 1216                                               Not at all
# 1338                      Implementing our own cryptocurrency
# ...                                                       ...
# 88677                                                     NaN
# 27544                                                     NaN
# 29998       Accepting Bitcoin or other coins and tokens as...
# 44923                                                     NaN
# 76444                                              Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 71          Useful across many domains and could change ma...        Yes
# 940                                                       NaN        Yes
# 1003        Useful for immutable record keeping outside of...        Yes
# 1216        Useful across many domains and could change ma...        Yes
# 1338                                                      NaN        Yes
# ...                                                       ...        ...
# 88677       Useful across many domains and could change ma...        Yes
# 27544                                                     NaN        Yes
# 29998       Useful across many domains and could change ma...        Yes
# 44923                                                     NaN        Yes
# 76444       Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                             ITperson  OffOn SocialMedia  \
# Respondent
# 71                                          Also Yes    Yes    Facebook
# 940                                              Yes    Yes    Facebook
# 1003                                             Yes    Yes      Reddit
# 1216                                             Yes  What?    Facebook
# 1338                                             Yes    Yes     Twitter
# ...                                              ...    ...         ...
# 88677                                            Yes     No     YouTube
# 27544                                            Yes  What?   Instagram
# 29998                                            Yes  What?    Facebook
# 44923       Fortunately, someone else has that title  What?    Facebook
# 76444       Fortunately, someone else has that title     No    Facebook
#
#                         Extraversion   ScreenName        SOVisit1st  \
# Respondent
# 71          In real life (in person)     Username              2013
# 940                           Online     Username              2016
# 1003        In real life (in person)     Username              2016
# 1216                         Neither          NaN              2012
# 1338        In real life (in person)  Screen Name              2013
# ...                              ...          ...               ...
# 88677       In real life (in person)  Screen Name              2014
# 27544                         Online        Login              2018
# 29998                         Online        Login  I don't remember
# 44923       In real life (in person)          NaN              2019
# 76444                         Online       UserID              2018
#
#                                                   SOVisitFreq  \
# Respondent
# 71                                      Daily or almost daily
# 940                                     Daily or almost daily
# 1003                          A few times per month or weekly
# 1216                                   Multiple times per day
# 1338                                    Daily or almost daily
# ...                                                       ...
# 88677                                  Multiple times per day
# 27544       I have never visited Stack Overflow (before to...
# 29998       I have never visited Stack Overflow (before to...
# 44923       I have never visited Stack Overflow (before to...
# 76444                                   Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 71          Find answers to specific questions;Pass the ti...
# 940         Learn how to do things I didn’t necessarily lo...
# 1003                       Find answers to specific questions
# 1216        Find answers to specific questions;Learn how t...
# 1338                       Find answers to specific questions
# ...                                                       ...
# 88677                      Find answers to specific questions
# 27544                                   Pass the time / relax
# 29998       Get a sense of belonging to the developer comm...
# 44923       Find answers to specific questions;Learn how t...
# 76444       Get a sense of belonging to the developer comm...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 71                   3-5 times per week            They were about the same
# 940             Less than once per week  Stack Overflow was slightly faster
# 1003                 3-5 times per week  Stack Overflow was slightly faster
# 1216        More than 10 times per week      Stack Overflow was much faster
# 1338        More than 10 times per week      Stack Overflow was much faster
# ...                                 ...                                 ...
# 88677                               NaN                                 NaN
# 27544           Less than once per week  Stack Overflow was slightly faster
# 29998                3-5 times per week      Stack Overflow was much faster
# 44923                3-5 times per week            They were about the same
# 76444           Less than once per week  Stack Overflow was slightly faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 71                    NaN                        Yes
# 940         31-60 minutes                        Yes
# 1003         0-10 minutes                        Yes
# 1216          60+ minutes                        Yes
# 1338        11-30 minutes  Not sure / can't remember
# ...                   ...                        ...
# 88677                 NaN                        Yes
# 27544       11-30 minutes                        NaN
# 29998       11-30 minutes                        NaN
# 44923                 NaN                        NaN
# 76444       11-30 minutes                         No
#
#                                                    SOPartFreq  \
# Respondent
# 71                                       A few times per week
# 940         I have never participated in Q&A on Stack Over...
# 1003        I have never participated in Q&A on Stack Over...
# 1216                          A few times per month or weekly
# 1338                                                      NaN
# ...                                                       ...
# 88677                         A few times per month or weekly
# 27544                                                     NaN
# 29998                                                     NaN
# 44923                                                     NaN
# 76444                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 71                                                        Yes
# 940         No, I didn't know that Stack Overflow had a jo...
# 1003                                                      Yes
# 1216                                                      Yes
# 1338        No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 88677                                                     Yes
# 27544       No, I didn't know that Stack Overflow had a jo...
# 29998       No, I didn't know that Stack Overflow had a jo...
# 44923       No, I didn't know that Stack Overflow had a jo...
# 76444                                                     Yes
#
#                                                      EntTeams  \
# Respondent
# 71          No, I've heard of them, but I am not part of a...
# 940                       No, and I don't know what those are
# 1003                      No, and I don't know what those are
# 1216        No, I've heard of them, but I am not part of a...
# 1338                      No, and I don't know what those are
# ...                                                       ...
# 88677                     No, and I don't know what those are
# 27544                     No, and I don't know what those are
# 29998                     No, and I don't know what those are
# 44923                     No, and I don't know what those are
# 76444                                                     Yes
#
#                      SOComm  \
# Respondent
# 71          Yes, definitely
# 940                 Neutral
# 1003         No, not really
# 1216        Yes, definitely
# 1338                Neutral
# ...                     ...
# 88677       Yes, definitely
# 27544               Neutral
# 29998              Not sure
# 44923       Yes, definitely
# 76444        No, not at all
#
#                                                 WelcomeChange  \
# Respondent
# 71                      A lot more welcome now than last year
# 940                     A lot less welcome now than last year
# 1003                  Just as welcome now as I felt last year
# 1216                 Somewhat less welcome now than last year
# 1338                  Just as welcome now as I felt last year
# ...                                                       ...
# 88677                   A lot more welcome now than last year
# 27544                Somewhat less welcome now than last year
# 29998       Not applicable - I did not use Stack Overflow ...
# 44923       Not applicable - I did not use Stack Overflow ...
# 76444       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 71          Tech articles written by other developers;Tech...  21.0  Woman
# 940                 Tech articles written by other developers   NaN    Man
# 1003        Tech articles written by other developers;Indu...  19.0    Man
# 1216        Industry news about technologies you're intere...  25.0    Man
# 1338        Tech meetups or events in your area;Courses on...   NaN    NaN
# ...                                                       ...   ...    ...
# 88677                                                     NaN  31.0    Man
# 27544       Industry news about technologies you're intere...  42.0    Man
# 29998       Tech articles written by other developers;Indu...  33.0  Woman
# 44923       Tech articles written by other developers;Indu...  37.0  Woman
# 76444                                                     NaN   NaN    Man
#
#            Trans                Sexuality                           Ethnicity  \
# Respondent
# 71            No  Straight / Heterosexual              East Asian;South Asian
# 940           No  Straight / Heterosexual              East Asian;South Asian
# 1003          No                 Bisexual                         South Asian
# 1216          No  Straight / Heterosexual  East Asian;South Asian;Multiracial
# 1338         NaN                      NaN                                 NaN
# ...          ...                      ...                                 ...
# 88677         No  Straight / Heterosexual                          East Asian
# 27544         No                      NaN                         South Asian
# 29998         No                      NaN                                 NaN
# 44923         No                      NaN                                 NaN
# 76444         No                      NaN        White or of European descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 71                 No  Appropriate in length                        Easy
# 940               Yes               Too long  Neither easy nor difficult
# 1003              Yes               Too long  Neither easy nor difficult
# 1216               No               Too long  Neither easy nor difficult
# 1338              NaN               Too long                   Difficult
# ...               ...                    ...                         ...
# 88677             Yes  Appropriate in length                        Easy
# 27544             Yes               Too long  Neither easy nor difficult
# 29998             Yes               Too long                        Easy
# 44923             Yes               Too long  Neither easy nor difficult
# 76444             Yes               Too long                   Difficult
#
# [381 rows x 84 columns]

# %%
country_grp.get_group('Philippines')['SocialMedia'].value_counts().head(50)
# Out:
# Facebook                    200
# YouTube                      72
# Reddit                       37
# Twitter                      25
# Instagram                    12
# I don't use social media     10
# LinkedIn                      8
# WhatsApp                      4
# Hello                         1
# WeChat 微信                     1
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['Philippines']
# Out:
# SocialMedia
# Facebook                    200
# YouTube                      72
# Reddit                       37
# Twitter                      25
# Instagram                    12
# I don't use social media     10
# LinkedIn                      8
# WhatsApp                      4
# Hello                         1
# Snapchat                      1
# WeChat 微信                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['Germany']
# Out:
# SocialMedia
# WhatsApp                    1343
# YouTube                      970
# Reddit                       923
# Twitter                      866
# I don't use social media     501
# Facebook                     404
# Instagram                    264
# LinkedIn                     141
# Snapchat                      10
# VK ВКонта́кте                  8
# WeChat 微信                      8
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Germany']
# Out:
# median     63016.000000
# mean      109256.884066
# Name: Germany, dtype: float64

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# ...                                                       ...
# 77339                                 Less than once per year
# 79795       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                        NaN
# ...                                                       ...
# 77339       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India             NaN
# 10                          Employed full-time   India              No
# 15          Not employed, but looking for work   India  Yes, full-time
# 50                          Employed full-time   India              No
# 65                          Employed full-time   India              No
# ...                                        ...     ...             ...
# 77339                       Employed full-time   India  Yes, full-time
# 79795                       Employed full-time   India              No
# 83862                       Employed full-time   India  Yes, full-time
# 84299                       Employed full-time   India  Yes, full-time
# 86012                       Employed full-time   India              No
#
#                                                       EdLevel  \
# Respondent
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Secondary school (e.g. American high school, G...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 77339                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 15                                                        NaN
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# ...                                                       ...
# 77339       Another engineering discipline (ex. civil, ele...
# 79795       Computer science, computer engineering, or sof...
# 83862                                                     NaN
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 8           Taught yourself a new language, framework, or ...
# 10                                                        NaN
# 15          Taken an online course in programming or softw...
# 50          Received on-the-job training in software devel...
# 65                                                        NaN
# ...                                                       ...
# 77339       Taken an online course in programming or softw...
# 79795       Taken an online course in programming or softw...
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 86012       Taught yourself a new language, framework, or ...
#
#                              OrgSize  \
# Respondent
# 8                                NaN
# 10          10,000 or more employees
# 15                               NaN
# 50          10,000 or more employees
# 65                20 to 99 employees
# ...                              ...
# 77339       1,000 to 4,999 employees
# 79795           500 to 999 employees
# 83862                            NaN
# 84299           100 to 499 employees
# 86012           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 8              Developer, back-end;Engineer, site reliability         8
# 10          Data or business analyst;Data scientist or mac...        12
# 15                                                    Student         3
# 50                      Developer, back-end;DevOps specialist         7
# 65                     Developer, front-end;Developer, mobile         2
# ...                                                       ...       ...
# 77339                                                     NaN         1
# 79795                                   Developer, QA or test         6
# 83862                        Data or business analyst;Student         1
# 84299       Developer, back-end;Developer, front-end;Devel...        12
# 86012                            Academic researcher;Educator         5
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 8                  16               NaN                    NaN
# 10                 20                10  Slightly dissatisfied
# 15                 13               NaN                    NaN
# 50                 15                 2     Slightly satisfied
# 65                 17                 2         Very satisfied
# ...               ...               ...                    ...
# 77339              27                 1                    NaN
# 79795              17                 5                    NaN
# 83862              18  Less than 1 year                    NaN
# 84299              25                12                    NaN
# 86012              15               NaN                    NaN
#
#                            JobSat            MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 8                             NaN                 NaN       NaN       NaN
# 10          Slightly dissatisfied  Somewhat confident       Yes       Yes
# 15                            NaN                 NaN       NaN       NaN
# 50                 Very satisfied      Very confident  Not sure       Yes
# 65                 Very satisfied      Very confident        No  Not sure
# ...                           ...                 ...       ...       ...
# 77339                         NaN  Somewhat confident       Yes       Yes
# 79795                         NaN  Somewhat confident        No  Not sure
# 83862                         NaN      Very confident  Not sure       Yes
# 84299                         NaN                 NaN       NaN       NaN
# 86012                         NaN  Somewhat confident        No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 8                                                         NaN
# 10          I’m not actively looking, but I am open to new...
# 15          I’m not actively looking, but I am open to new...
# 50          I’m not actively looking, but I am open to new...
# 65          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 8                            NaN
# 10                 3-4 years ago
# 15          I've never had a job
# 50                 1-2 years ago
# 65          Less than a year ago
# ...                          ...
# 77339                        NaN
# 79795                        NaN
# 83862                        NaN
# 84299                        NaN
# 86012                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 8                                                         NaN      NaN
# 10                                                        NaN       No
# 15                                                        NaN      NaN
# 50          Write code by hand (e.g., on a whiteboard);Int...       No
# 65          Write any code;Solve a brain-teaser style puzz...       No
# ...                                                       ...      ...
# 77339                                                     NaN      NaN
# 79795                                                     NaN      NaN
# 83862                                                     NaN      NaN
# 84299                                                     NaN      NaN
# 86012                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 8                                                         NaN
# 10          Languages, frameworks, and other technologies ...
# 15          Industry that I'd be working in;Languages, fra...
# 50          Specific department or team I'd be working on;...
# 65          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 8                                                         NaN            NaN
# 10                                                        NaN            INR
# 15          Something else changed (education, award, medi...            NaN
# 50                           I was preparing for a job search            INR
# 65           My job status changed (promotion, new job, etc.)            INR
# ...                                                       ...            ...
# 77339                                                     NaN            NaN
# 79795                                                     NaN            NaN
# 83862                                                     NaN            NaN
# 84299                                                     NaN            NaN
# 86012                                                     NaN            NaN
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 8                    NaN        NaN      NaN            NaN          NaN
# 10          Indian rupee   950000.0   Yearly        13293.0         70.0
# 15                   NaN        NaN      NaN            NaN          NaN
# 50          Indian rupee   400000.0   Yearly         5597.0          7.0
# 65          Indian rupee        NaN  Monthly            NaN         48.0
# ...                  ...        ...      ...            ...          ...
# 77339                NaN        NaN      NaN            NaN          NaN
# 79795                NaN        NaN      NaN            NaN          NaN
# 83862                NaN        NaN      NaN            NaN          NaN
# 84299                NaN        NaN      NaN            NaN          NaN
# 86012                NaN        NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 8                                                         NaN
# 10          There's no schedule or spec; I work on what se...
# 15                                                        NaN
# 50          There is a schedule and/or spec (made by me or...
# 65          There's no schedule or spec; I work on what se...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                             WorkChallenge                        WorkRemote  \
# Respondent
# 8                                     NaN                               NaN
# 10                                    NaN             A few days each month
# 15                                    NaN                               NaN
# 50          Meetings;Time spent commuting  Less than once per month / Never
# 65                                    NaN               About half the time
# ...                                   ...                               ...
# 77339                                 NaN                               NaN
# 79795                                 NaN                               NaN
# 83862                                 NaN                               NaN
# 84299                                 NaN                               NaN
# 86012                                 NaN                               NaN
#
#                                                    WorkLoc             ImpSyn  \
# Respondent
# 8                                                      NaN                NaN
# 10                                                    Home  Far above average
# 15                                                     NaN                NaN
# 50          Other place, such as a coworking space or cafe            Average
# 65                                                  Office            Average
# ...                                                    ...                ...
# 77339                                                  NaN                NaN
# 79795                                                  NaN                NaN
# 83862                                                  NaN                NaN
# 84299                                                  NaN                NaN
# 86012                                                  NaN                NaN
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 8                                               NaN         NaN
# 10          Yes, because I see value in code review         4.0
# 15                                              NaN         NaN
# 50                                               No         NaN
# 65          Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 77339                                           NaN         NaN
# 79795                                           NaN         NaN
# 83862                                           NaN         NaN
# 84299                                           NaN         NaN
# 86012                                           NaN         NaN
#
#                                                     UnitTests  \
# Respondent
# 8                                                         NaN
# 10                              Yes, it's part of our process
# 15                                                        NaN
# 50          Yes, it's not part of our process but the deve...
# 65          Yes, it's not part of our process but the deve...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                   PurchaseHow  \
# Respondent
# 8                                                         NaN
# 10                                                        NaN
# 15                                                        NaN
# 50          The CTO, CIO, or other management purchase new...
# 65                                                   Not sure
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                              PurchaseWhat  \
# Respondent
# 8                                     NaN
# 10                                    NaN
# 15                                    NaN
# 50          I have little or no influence
# 65                                    NaN
# ...                                   ...
# 77339                                 NaN
# 79795                                 NaN
# 83862                                 NaN
# 84299                                 NaN
# 86012                                 NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# 77339                                               Other(s):
# 79795                    Bash/Shell/PowerShell;Python;SQL;VBA
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                                 HTML/CSS;JavaScript;Python
# 65                                                     Kotlin
# ...                                                       ...
# 77339                                              Python;SQL
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                HTML/CSS;Java;JavaScript
# 86012                                              C++;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                                MariaDB;MySQL;Oracle;SQLite
# 50          Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                               Firebase;MySQL;Oracle;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                   MySQL
# 84299                                    MongoDB;Redis;SQLite
# 86012                                                   MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
# 15          MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                        Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862             Android;AWS;Google Cloud Platform;WordPress
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                        PlatformDesireNextYear  \
# Respondent
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                         Android;Linux;Raspberry Pi;Windows
# 15          Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50          AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                     IBM Cloud or Watson
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                            WebFrameWorkedWith  \
# Respondent
# 8                               Express;Flask;React.js;Spring
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                        NaN
# 50                                Django;Express;Flask;jQuery
# 65                                                    ASP.NET
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Laravel
# 84299       Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                                     NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 8                        Django;Express;Flask;React.js;Vue.js
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15          Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                       Express;Flask;jQuery;React.js;Vue.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                       Angular/Angular.js;Laravel;Vue.js
# 84299                              Express;React.js;Other(s):
# 86012                                                     NaN
#
#                            MiscTechWorkedWith  \
# Respondent
# 8                       Hadoop;Node.js;Pandas
# 10          .NET;Node.js;Pandas;Torch/PyTorch
# 15                                        NaN
# 50                                    Node.js
# 65                                        NaN
# ...                                       ...
# 77339                                     NaN
# 79795                Apache Spark;Chef;Puppet
# 83862                                     NaN
# 84299                                 Node.js
# 86012                                     NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
# 15          .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                                    Node.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Node.js
# 84299                                                 Node.js
# 86012                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15                   Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                               Notepad++;Visual Studio Code        MacOS
# 65                                    Android Studio;IntelliJ  Linux-based
# ...                                                       ...          ...
# 77339                                                     NaN  Linux-based
# 79795                                             PyCharm;Vim  Linux-based
# 83862       Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299             IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                               Notepad++  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 8           Development;Testing;Production;Outside of work...           NaN
# 10                                                        NaN    Not at all
# 15                                                Development           NaN
# 50                                                    Testing    Not at all
# 65                                                        NaN           NaN
# ...                                                       ...           ...
# 77339                                 I do not use containers           NaN
# 79795       Development;Testing;Production;Outside of work...    Not at all
# 83862                                 I do not use containers           NaN
# 84299                                                     NaN           NaN
# 86012                                 I do not use containers           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 8           Useful across many domains and could change ma...        Yes
# 10          Useful for immutable record keeping outside of...         No
# 15                                                        NaN        Yes
# 50          Useful for immutable record keeping outside of...        Yes
# 65                                                        NaN        Yes
# ...                                                       ...        ...
# 77339                                                     NaN        Yes
# 79795                                                     NaN         No
# 83862       Useful across many domains and could change ma...         No
# 84299                                                     NaN        Yes
# 86012                                                     NaN         No
#
#                                             ITperson  OffOn  \
# Respondent
# 8                                               SIGH    Yes
# 10                                               Yes    Yes
# 15                                               Yes  What?
# 50                                          Also Yes  What?
# 65                                               Yes  What?
# ...                                              ...    ...
# 77339                                            Yes     No
# 79795                                            Yes  What?
# 83862                                            Yes  What?
# 84299       Fortunately, someone else has that title  What?
# 86012                                       Also Yes  What?
#
#                          SocialMedia              Extraversion   ScreenName  \
# Respondent
# 8                            YouTube  In real life (in person)       Handle
# 10                           YouTube                   Neither  Screen Name
# 15                           YouTube  In real life (in person)          NaN
# 50                           YouTube  In real life (in person)     Username
# 65                          WhatsApp  In real life (in person)          NaN
# ...                              ...                       ...          ...
# 77339                        YouTube                    Online       UserID
# 79795                      Instagram  In real life (in person)     Username
# 83862                        Twitter                    Online       UserID
# 84299                       LinkedIn                       NaN          NaN
# 86012       I don't use social media                    Online     Username
#
#            SOVisit1st                          SOVisitFreq  \
# Respondent
# 8                2012                 A few times per week
# 10                NaN               Multiple times per day
# 15               2018                Daily or almost daily
# 50               2012                Daily or almost daily
# 65               2017               Multiple times per day
# ...               ...                                  ...
# 77339            2019  Less than once per month or monthly
# 79795            2018      A few times per month or weekly
# 83862            2012      A few times per month or weekly
# 84299            2011      A few times per month or weekly
# 86012            2014      A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 8           Find answers to specific questions;Learn how t...
# 10          Find answers to specific questions;Get a sense...
# 15          Find answers to specific questions;Learn how t...
# 50          Find answers to specific questions;Learn how t...
# 65                         Find answers to specific questions
# ...                                                       ...
# 77339       Find answers to specific questions;Learn how t...
# 79795                      Find answers to specific questions
# 83862       Find answers to specific questions;Learn how t...
# 84299       Find answers to specific questions;Contribute ...
# 86012                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 8               Less than once per week  Stack Overflow was slightly faster
# 10                   3-5 times per week            They were about the same
# 15          More than 10 times per week            They were about the same
# 50                   3-5 times per week  Stack Overflow was slightly faster
# 65          More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 77339                1-2 times per week      Stack Overflow was much faster
# 79795           Less than once per week            They were about the same
# 83862           Less than once per week      Stack Overflow was much faster
# 84299           Less than once per week      Stack Overflow was much faster
# 86012           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 8           11-30 minutes       Yes
# 10                    NaN       Yes
# 15                    NaN       Yes
# 50          11-30 minutes       Yes
# 65          11-30 minutes       Yes
# ...                   ...       ...
# 77339       31-60 minutes       Yes
# 79795                 NaN       Yes
# 83862        0-10 minutes       Yes
# 84299         60+ minutes       Yes
# 86012       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 8                         Less than once per month or monthly
# 10                            A few times per month or weekly
# 15                        Less than once per month or monthly
# 50                        Less than once per month or monthly
# 65                                       A few times per week
# ...                                                       ...
# 77339       I have never participated in Q&A on Stack Over...
# 79795       I have never participated in Q&A on Stack Over...
# 83862       I have never participated in Q&A on Stack Over...
# 84299                     Less than once per month or monthly
# 86012                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 8                                                         Yes
# 10                                                        Yes
# 15                                                        Yes
# 50          No, I knew that Stack Overflow had a job board...
# 65          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 77339       No, I didn't know that Stack Overflow had a jo...
# 79795       No, I didn't know that Stack Overflow had a jo...
# 83862                                                     Yes
# 84299                                                     Yes
# 86012       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 8                         No, and I don't know what those are
# 10                        No, and I don't know what those are
# 15          No, I've heard of them, but I am not part of a...
# 50                        No, and I don't know what those are
# 65                        No, and I don't know what those are
# ...                                                       ...
# 77339       No, I've heard of them, but I am not part of a...
# 79795                     No, and I don't know what those are
# 83862                     No, and I don't know what those are
# 84299                     No, and I don't know what those are
# 86012                                                     Yes
#
#                      SOComm  \
# Respondent
# 8           Yes, definitely
# 10            Yes, somewhat
# 15            Yes, somewhat
# 50          Yes, definitely
# 65                 Not sure
# ...                     ...
# 77339         Yes, somewhat
# 79795               Neutral
# 83862       Yes, definitely
# 84299         Yes, somewhat
# 86012         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# ...                                                       ...
# 77339       Not applicable - I did not use Stack Overflow ...
# 79795                Somewhat more welcome now than last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN    NaN
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                        NaN  21.0    Man
# ...                                                       ...   ...    ...
# 77339       Tech articles written by other developers;Indu...   NaN    NaN
# 79795       Tech meetups or events in your area;Courses on...   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                     NaN   NaN    NaN
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual          NaN        NaN
# 10           NaN                      NaN          NaN        Yes
# 15            No                      NaN          NaN        Yes
# 50            No                      NaN  South Asian         No
# 65            No                      NaN          NaN        Yes
# ...          ...                      ...          ...        ...
# 77339        NaN                      NaN          NaN        NaN
# 79795         No  Straight / Heterosexual          NaN         No
# 83862         No  Straight / Heterosexual          NaN        Yes
# 84299        NaN                      NaN          NaN        NaN
# 86012         No                      NaN  South Asian        NaN
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 77339                         NaN                         NaN
# 79795                    Too long                   Difficult
# 83862                    Too long  Neither easy nor difficult
# 84299                         NaN                         NaN
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                           C#;Go;JavaScript;Python;R;SQL
# 15       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                         Assembly;C;C++;C#;HTML/CSS;Java
#                                ...
# 77339                                            Other(s):
# 79795                 Bash/Shell/PowerShell;Python;SQL;VBA
# 83862    Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 8         True
# 10        True
# 15       False
# 50        True
# 65       False
#          ...
# 77339    False
# 79795     True
# 83862    False
# 84299     True
# 86012    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda series: series.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
# What % of people from each county know Python?

# trial answer

country_grp.apply(lambda series: series.str.contains('Python').sum()).value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [64], in <cell line: 3>()
#       1 # What % of people from each county know Python?
# ----> 3 country_grp.apply(lambda series: series.str.contains('Python').sum()).value_counts(normalize=True)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1414, in GroupBy.apply(self, func, *args, **kwargs)
#    1412 with option_context("mode.chained_assignment", None):
#    1413     try:
# -> 1414         result = self._python_apply_general(f, self._selected_obj)
#    1415     except TypeError:
#    1416         # gh-20949
#    1417         # try again, with .apply acting as a filtering
#    (...)
#    1421         # fails on *some* columns, e.g. a numeric operation
#    1422         # on a string grouper column
#    1424         with self._group_selection_context():
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1429 @final
#    1430 def _python_apply_general(
#    1431     self,
#    (...)
#    1434     not_indexed_same: bool | None = None,
#    1435 ) -> DataFrame | Series:
#    1436     """
#    1437     Apply function f in python space
#    1438
#    (...)
#    1453         data after applying f
#    1454     """
# -> 1455     values, mutated = self.grouper.apply(f, data, self.axis)
#    1457     if not_indexed_same is None:
#    1458         not_indexed_same = mutated or self.mutated
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     759 # group might be modified
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763     mutated = True
#
# Input In [64], in <lambda>(series)
#       1 # What % of people from each county know Python?
# ----> 3 country_grp.apply(lambda series: series.str.contains('Python').sum()).value_counts(normalize=True)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda series: series.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python])
python_df
# Out:
# United States                           20949
# India                                    9061
# Germany                                  5866
# United Kingdom                           5737
# Canada                                   3395
#                                         ...
# Venezuela, Bolivarian Republic of...       28
# Viet Nam                                   78
# Yemen                                       3
# Zambia                                      4
# Zimbabwe                                   14
# Length: 358, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')

# %%
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)

# %%
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumberOfRespondents', 'LanguageWorkedWith': "NumberOfRespondentsKnowsPython"})
# Out:
#                    NumberOfRespondents  NumberOfRespondentsKnowsPython
# United States                    20949                           10083
# India                             9061                            3105
# Germany                           5866                            2451
# United Kingdom                    5737                            2384
# Canada                            3395                            1558
# ...                                ...                             ...
# Tonga                                1                               0
# Timor-Leste                          1                               1
# North Korea                          1                               0
# Brunei Darussalam                    1                               0
# Chad                                 1                               0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumberOfRespondents', 'LanguageWorkedWith': "NumberOfRespondentsKnowsPython"}, inplace=True)

# %%
python_df
# Out:
#                    NumberOfRespondents  NumberOfRespondentsKnowsPython
# United States                    20949                           10083
# India                             9061                            3105
# Germany                           5866                            2451
# United Kingdom                    5737                            2384
# Canada                            3395                            1558
# ...                                ...                             ...
# Tonga                                1                               0
# Timor-Leste                          1                               1
# North Korea                          1                               0
# Brunei Darussalam                    1                               0
# Chad                                 1                               0
#
# [179 rows x 2 columns]

# %%
python_df['PercentageKnowsPythonPerCountry'] = (python_df['NumberOfRespondentsKnowsPython'] / python_df['NumberOfRespondents'] * 100)

# %%
python_df
# Out:
#                    NumberOfRespondents  NumberOfRespondentsKnowsPython  \
# United States                    20949                           10083
# India                             9061                            3105
# Germany                           5866                            2451
# United Kingdom                    5737                            2384
# Canada                            3395                            1558
# ...                                ...                             ...
# Tonga                                1                               0
# Timor-Leste                          1                               1
# North Korea                          1                               0
# Brunei Darussalam                    1                               0
# Chad                                 1                               0
#
#                    KnowsPythonPerCountry  PercentageKnowsPythonPerCountry
# United States                  48.131176                        48.131176
# India                          34.267741                        34.267741
# Germany                        41.783157                        41.783157
# United Kingdom                 41.554820                        41.554820
# Canada                         45.891016                        45.891016
# ...                                  ...                              ...
# Tonga                           0.000000                         0.000000
# Timor-Leste                   100.000000                       100.000000
# North Korea                     0.000000                         0.000000
# Brunei Darussalam               0.000000                         0.000000
# Chad                            0.000000                         0.000000
#
# [179 rows x 4 columns]

# %%
python_df.sort_values(by='PercentageKnowsPythonPerCountry', ascending=False)
# Out:
#                                   NumberOfRespondents  \
# Sao Tome and Principe                               1
# Timor-Leste                                         1
# Dominica                                            1
# Niger                                               1
# Turkmenistan                                        7
# ...                                               ...
# Cape Verde                                          3
# Lao People's Democratic Republic                    3
# Malawi                                              2
# Liberia                                             2
# Chad                                                1
#
#                                   NumberOfRespondentsKnowsPython  \
# Sao Tome and Principe                                          1
# Timor-Leste                                                    1
# Dominica                                                       1
# Niger                                                          1
# Turkmenistan                                                   6
# ...                                                          ...
# Cape Verde                                                     0
# Lao People's Democratic Republic                               0
# Malawi                                                         0
# Liberia                                                        0
# Chad                                                           0
#
#                                   KnowsPythonPerCountry  \
# Sao Tome and Principe                        100.000000
# Timor-Leste                                  100.000000
# Dominica                                     100.000000
# Niger                                        100.000000
# Turkmenistan                                  85.714286
# ...                                                 ...
# Cape Verde                                     0.000000
# Lao People's Democratic Republic               0.000000
# Malawi                                         0.000000
# Liberia                                        0.000000
# Chad                                           0.000000
#
#                                   PercentageKnowsPythonPerCountry
# Sao Tome and Principe                                  100.000000
# Timor-Leste                                            100.000000
# Dominica                                               100.000000
# Niger                                                  100.000000
# Turkmenistan                                            85.714286
# ...                                                           ...
# Cape Verde                                               0.000000
# Lao People's Democratic Republic                         0.000000
# Malawi                                                   0.000000
# Liberia                                                  0.000000
# Chad                                                     0.000000
#
# [179 rows x 4 columns]

# %%
python_df.head(50)
# Out:
#                     NumberOfRespondents  NumberOfRespondentsKnowsPython  \
# United States                     20949                           10083
# India                              9061                            3105
# Germany                            5866                            2451
# United Kingdom                     5737                            2384
# Canada                             3395                            1558
# France                             2391                            1054
# Brazil                             1948                             767
# Poland                             1922                             751
# Australia                          1903                             790
# Netherlands                        1852                             767
# Russian Federation                 1694                             708
# Spain                              1604                             641
# Italy                              1576                             625
# Sweden                             1274                             496
# Switzerland                         978                             460
# Israel                              952                             457
# Turkey                              949                             371
# Pakistan                            923                             251
# Ukraine                             868                             246
# Austria                             839                             338
# Czech Republic                      764                             285
# Romania                             760                             253
# Iran                                738                             268
# Belgium                             727                             296
# China                               664                             297
# Bulgaria                            659                             181
# Mexico                              642                             245
# South Africa                        627                             202
# Denmark                             617                             246
# Bangladesh                          605                             204
# Norway                              574                             232
# Greece                              556                             226
# Argentina                           553                             191
# Finland                             546                             266
# Portugal                            525                             182
# New Zealand                         524                             236
# Nigeria                             522                             152
# Hungary                             513                             191
# Indonesia                           507                             148
# Ireland                             501                             209
# Serbia                              402                             117
# Japan                               391                             182
# Philippines                         381                             117
# Sri Lanka                           372                             137
# Egypt                               323                             111
# Colombia                            313                             108
# Singapore                           303                             139
# Malaysia                            299                              95
# Slovenia                            298                             119
# Slovakia                            260                             101
#
#                     KnowsPythonPerCountry  PercentageKnowsPythonPerCountry
# United States                   48.131176                        48.131176
# India                           34.267741                        34.267741
# Germany                         41.783157                        41.783157
# United Kingdom                  41.554820                        41.554820
# Canada                          45.891016                        45.891016
# France                          44.081974                        44.081974
# Brazil                          39.373717                        39.373717
# Poland                          39.073881                        39.073881
# Australia                       41.513400                        41.513400
# Netherlands                     41.414687                        41.414687
# Russian Federation              41.794569                        41.794569
# Spain                           39.962594                        39.962594
# Italy                           39.657360                        39.657360
# Sweden                          38.932496                        38.932496
# Switzerland                     47.034765                        47.034765
# Israel                          48.004202                        48.004202
# Turkey                          39.093783                        39.093783
# Pakistan                        27.193933                        27.193933
# Ukraine                         28.341014                        28.341014
# Austria                         40.286055                        40.286055
# Czech Republic                  37.303665                        37.303665
# Romania                         33.289474                        33.289474
# Iran                            36.314363                        36.314363
# Belgium                         40.715268                        40.715268
# China                           44.728916                        44.728916
# Bulgaria                        27.465857                        27.465857
# Mexico                          38.161994                        38.161994
# South Africa                    32.216906                        32.216906
# Denmark                         39.870340                        39.870340
# Bangladesh                      33.719008                        33.719008
# Norway                          40.418118                        40.418118
# Greece                          40.647482                        40.647482
# Argentina                       34.538879                        34.538879
# Finland                         48.717949                        48.717949
# Portugal                        34.666667                        34.666667
# New Zealand                     45.038168                        45.038168
# Nigeria                         29.118774                        29.118774
# Hungary                         37.231969                        37.231969
# Indonesia                       29.191321                        29.191321
# Ireland                         41.716567                        41.716567
# Serbia                          29.104478                        29.104478
# Japan                           46.547315                        46.547315
# Philippines                     30.708661                        30.708661
# Sri Lanka                       36.827957                        36.827957
# Egypt                           34.365325                        34.365325
# Colombia                        34.504792                        34.504792
# Singapore                       45.874587                        45.874587
# Malaysia                        31.772575                        31.772575
# Slovenia                        39.932886                        39.932886
# Slovakia                        38.846154                        38.846154

# %%
python_df.loc['Japan']
# Out:
# NumberOfRespondents                391.000000
# NumberOfRespondentsKnowsPython     182.000000
# KnowsPythonPerCountry               46.547315
# PercentageKnowsPythonPerCountry     46.547315
# Name: Japan, dtype: float64

# %%
python_df.loc['Brazil']
# Out:
# NumberOfRespondents                1948.000000
# NumberOfRespondentsKnowsPython      767.000000
# KnowsPythonPerCountry                39.373717
# PercentageKnowsPythonPerCountry      39.373717
# Name: Brazil, dtype: float64

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## Practice Tasks

# %%
# Load a clean DataFrame.
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent")

# %% [markdown]
# #### 1. Create an overview of the coding experience ("YearsCode" column; mean) and the compensation ("ConvertedComp"; median) per country. To do so, change the data type from the "YearsCode" column to float (replace "Less than 1 year" with 0 and "More than 50 years" with 51). Please return a DataFrame named *country_overview* that looks the following:
# | Country     |   YearsCode |   ConvertedComp |
# |:------------|------------:|----------------:|
# | Afghanistan |     7.31707 |            6222 |
# | Albania     |     6.51807 |           10818 |
# | ...         |     ...     |            ...  |
#
#
#
# <br />
# <details>
# <summary>
#     <font size="3" color="red"><b>Hints (click to expand)</b></font>
# </summary>
# <p>
#     <ul>
#         <li>First, replace the "less than" and "more than" statements within the YearsCode column. This way, you can set the data type of this column to float.</li>
#         <li>Group by the countries column.</li>
#         <li>To apply different aggregation methods to different columns, pass a dictionary to the agg method. The dictionary's keys correspond to the column names you want to aggregate, and the values indicate the specific aggregation method. For example, groupby_object.agg({"Column 1": "mean", "Column 2": "median"}).</li>
#     </ul>
# </p>
# </details>

# %%
# # START YOUR CODE HERE.

# #converting into float
# df["YearsCode"].replace("Less than 1 year", 0)
# df["YearsCode"].replace("More than 50 years", 51)
# df["YearsCode"] = df["YearsCode"].astype(float)

# # grouping by country
# country_grp = df.groupby('Country')

# # df['ConvertedComp'].median()
# # df['YearsCode'].mean()


# country_overview = country_grp.agg({"YearsCode": "mean", "ConvertedComp": "median"})

# country_overview
# # END YOUR CODE HERE.


# solution

df["YearsCode"].replace("Less than 1 year", 0, inplace = True)
df["YearsCode"].replace("More than 50 years", 51, inplace = True)
df["YearsCode"] = df["YearsCode"].astype(float)
groupby_object = df.groupby("Country")
country_overview = groupby_object.agg({"YearsCode": "mean", "ConvertedComp": "median"})

country_overview.rename(columns={'YearsCode': 'YearsCodeMean', 'ConvertedComp': 'ConvertedCompMedian'})

country_overview
# Out:
#                                       YearsCode  ConvertedComp
# Country
# Afghanistan                            7.317073         6222.0
# Albania                                6.518072        10818.0
# Algeria                                6.473684         7878.0
# Andorra                               10.500000       160931.0
# Angola                                 2.250000         7764.0
# ...                                         ...            ...
# Venezuela, Bolivarian Republic of...   9.477273         6384.0
# Viet Nam                               6.504386        11892.0
# Yemen                                  5.789474        11940.0
# Zambia                                 4.916667         5040.0
# Zimbabwe                               6.000000        19200.0
#
# [179 rows x 2 columns]

# %%
# THIS CELL TESTS YOUR RESULTS.
assert type(country_overview) == type(pd.DataFrame([])), "Please return a DataFrame!"
assert country_overview.loc["Germany", "YearsCode"] == 12.784108460614382, "Your results seem to be incorrect!"
assert country_overview.loc["United States", "ConvertedComp"] == 110000.0, "Your results seem to be incorrect!"
assert country_overview.loc["India", "ConvertedComp"] == 10080.0, "Your results seem to be incorrect!"

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Solution (click to expand)</b></font>
# </summary>
# <p>
#     <code>df["YearsCode"].replace("Less than 1 year", 0, inplace = True)</code><br />
#     <code>df["YearsCode"].replace("More than 50 years", 51, inplace = True)</code><br />
#     <code>df["YearsCode"] = df["YearsCode"].astype(float)</code><br />
#     <code>groupby_object = df.groupby("Country")</code><br />
#     <code>country_overview = groupby_object.agg({"YearsCode": "mean", "ConvertedComp": "median"})</code><br />
# </p>
# </details>
#
# #### 2. Create an overview that shows what percentage of respondents are very satisfied ("JobSat" column) with their current job per country ("Country" column). Return a Series object named *satisfied_percentage* that is sorted in descending order and looks the following:
# |             |          |
# |:------------|---------:|
# | Timor-Leste | 1        |
# | Belize      | 0.666667 |
# | ...         | ...      |
#
# <br />
# <details>
# <summary>
#     <font size="3" color="red"><b>Hints (click to expand)</b></font>
# </summary>
# <p>
#     <ul>
#         <li>Group by the country.</li>
#         <li>Then determine per country how often a participant answered "Very Satisfied" to the job satisfaction question.</li>
#         <li>Determine how many participants there was per country. Note that you previously excluded all participants who did not answer both questions.
# Arithmetic operations in Pandas are always performed so that the same indices are offset against each other. Your groupby-DataFrame and the CountryCount-DataFrame both have the countries as the index.</li>
#     </ul>
# </p>
# </details>

# %%
# # This drops every participant that did not answer both questions.
# task_df = df[["JobSat", "Country"]].dropna()
# # START YOUR CODE HERE.

# satisfied_percentage = task_df.sort_values(by="JobSat", ascending=False)
# satisfied_percentage
# # END YOUR CODE HERE.

# solution

task_df = df[["JobSat", "Country"]].dropna()
groupby_object = task_df.groupby("Country")
satisfied_per_country = groupby_object["JobSat"].apply(lambda x: (x == "Very satisfied").sum())
respondents_per_country = df["Country"].value_counts()
satisfied_percentage = (satisfied_per_country/respondents_per_country).sort_values(ascending = False)

satisfied_percentage
# Out:
# Timor-Leste              1.000000
# Belize                   0.666667
# San Marino               0.500000
# Bhutan                   0.500000
# Fiji                     0.400000
#                            ...
# North Korea                   NaN
# Papua New Guinea              NaN
# Saint Kitts and Nevis         NaN
# Sao Tome and Principe         NaN
# Tonga                         NaN
# Length: 179, dtype: float64

# %%
# THIS CELL TESTS YOUR RESULTS.
assert type(satisfied_percentage) == type(pd.Series([], dtype = "int64")), "Please return a Series!"
assert satisfied_percentage.loc["Germany"] == 0.24616433685646097, "Your results seem to be incorrect!"
assert satisfied_percentage.loc["United States"] == 0.3435486180724617, "Your results seem to be incorrect!"
assert satisfied_percentage.loc["India"] == 0.16410992164220284, "Your results seem to be incorrect!"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [103], in <cell line: 2>()
#       1 # THIS CELL TESTS YOUR RESULTS.
# ----> 2 assert type(satisfied_percentage) == type(pd.Series([], dtype = "int64")), "Please return a Series!"
#       3 assert satisfied_percentage.loc["Germany"] == 0.24616433685646097, "Your results seem to be incorrect!"
#       4 assert satisfied_percentage.loc["United States"] == 0.3435486180724617, "Your results seem to be incorrect!"
#
# AssertionError: Please return a Series!

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Solution (click to expand)</b></font>
# </summary>
# <p>
#     <code>task_df = df[["JobSat", "Country"]].dropna()</code><br />
#     <code>groupby_object = task_df.groupby("Country")</code><br />
#     <code>satisfied_per_country = groupby_object["JobSat"].apply(lambda x: (x == "Very satisfied").sum())</code><br />
#     <code>respondents_per_country = df["Country"].value_counts()</code><br />
#     <code>satisfied_percentage = (satisfied_per_country/respondents_per_country).sort_values(ascending = False)</code><br />
# </p>
# </details>
#
# #### 3. The mean is known to be strongly influenced by outliers. Therefore, create an overview showing how many participants per country receive a higher compensation (ConvertedComp column) than the respective country average. Contrast this column with how many people from each country (Country column) generally participated in the study. The first line of code is already given to include only participants that answered both questions. Please return a DataFrame named *comp_average* that looks like this:
# | Country     |   Number of respondents with an above average compensation |   Total number of respondents |
# |:------------|-----------------------------------------------------------:|------------------------------:|
# | Afghanistan |                                                          2 |                            12 |
# | Albania     |                                                         14 |                            50 |
# | ...         |                                                        ... |                           ... |
#
#
# <br />
# <details>
# <summary>
#     <font size="3" color="red"><b>Hints (click to expand)</b></font>
# </summary>
# <p>
#     <ul>
#         <li>There are several ways how to solve this task.</li>
#         <li>First, in any case, one must calculate the average compensation per country with a groupby operation.</li>
#         <li>Second, one should check per participant whether their compensation is above or below the mean compensation of their country. The resulting boolean values should be stored in a new column in the DataFrame.</li>
#         <li>Then one can perform a final groupby operation on the DataFrame by the countries. For the just determined above_average column, one determines the sum (because boolean values are handled like 0 and 1), and for the country column, the count.</li>
#     </ul>
#
# </p>
# </details>

# %%
# This drops every participant that did not answer both questions.
comp_average = df[["Country", "ConvertedComp"]].dropna()
# START YOUR CODE HERE.



# END YOUR CODE HERE.

# %%
# THIS CELL TESTS YOUR RESULTS.
import numpy as np
assert type(comp_average) == type(pd.DataFrame([])), "Please return a DataFrame!"
assert comp_average.shape == (161, 2), "Your DataFrame seems to have the wrong dimensions!"
assert np.array_equal(comp_average.loc["United States"].to_numpy(), [1911, 14981]), "Your results seem to be wrong!"
assert np.array_equal(comp_average.loc["Germany"].to_numpy(), [466, 3778]), "Your results seem to be wrong!"
assert np.array_equal(comp_average.loc["India"].to_numpy(), [677, 3999]), "Your results seem to be wrong!"

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Solution (click to expand)</b></font>
# </summary>
# <p>
#     <code>comp_average = df[["Country", "ConvertedComp"]].dropna()</code><br />
#     <code>country_mean = df.groupby("Country").agg({"ConvertedComp": "mean"})</code><br />
#     <code>comp_average["above_average"] = [compensation > country_mean.loc[country, "ConvertedComp"]</code><br />
#     <code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;for compensation, country in zip(comp_average["ConvertedComp"].values,</code><br />
#     <code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;comp_average["Country"].values)]</code><br />
#     <code>comp_average = comp_average.groupby(</code><br />
#     <code>&nbsp;&nbsp;&nbsp;&nbsp;"Country").agg({"above_average": "sum", "Country": "count"}).rename(</code><br />
#     <code>&nbsp;&nbsp;&nbsp;&nbsp;{"above_average": "Number of respondents with an above average compensation",</code><br />
#     <code>&nbsp;&nbsp;&nbsp;&nbsp; "Country": "Total number of respondents"}, axis = 1)</code><br />
# </p>
# </details>
